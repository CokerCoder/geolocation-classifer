# %%
import pandas as pd
import numpy as np

import nltk
import re

import gensim

import warnings
warnings.filterwarnings('ignore')

import multiprocessing
from tqdm import tqdm

from sklearn.feature_extraction.text import TfidfVectorizer

# %%
tweetData = pd.read_csv('data/train_full.csv', error_bad_lines=False) 
train_tweetContent = tweetData[['tweet']]
train_labels = tweetData['region']

tweetData = pd.read_csv('data/dev_full.csv', error_bad_lines=False)
dev_tweetContent = tweetData[['tweet']]
dev_labels = tweetData['region']

tweetData = pd.read_csv('data/test_full.csv', error_bad_lines=False) 
test_tweetContent = tweetData[['tweet']]
test_tweetID = tweetData['region']

# %%
train_tweetContent
# Out:
#                                                     tweet
# 0                                           Watching LOST
# 1                                    @USER_89a3500b i did
# 2       Maneuver so that I can put my team on, hopeful...
# 3       Darko was eating hamburgers in the locker room...
# 4       Girl pack ya bags i'm bout to take you on a ride!
# ...                                                   ...
# 133790  Wow...completely forgot that it's #FollowFrida...
# 133791  Some groovy Texas blues music is playing in my...
# 133792  @USER_8cac2975 Haven't seen that one in ages. ...
# 133793  RT @USER_6d0753d3: You should all go and follo...
# 133794                @USER_4cf8655a Congratulations. (-:
#
# [133795 rows x 1 columns]

# %%
'''
Preprocess a string.
:parameter
    :param text: string - name of column containing text
    :param lst_stopwords: list - list of stopwords to remove
    :param flg_stemm: bool - whether stemming is to be applied
    :param flg_lemm: bool - whether lemmitisation is to be applied
:return
    cleaned text
'''
def utils_preprocess_text(text, flg_stemm=False, flg_lemm=True, lst_stopwords=None):
    
    # remove @mentions (@USER)
#     text = re.sub(r'\B@USER\w+', '', text)
    
    ## clean (convert to lowercase and remove punctuations and characters and then strip)
    text = re.sub(r'[^\w\s]', '', str(text).lower().strip())
            
    ## Tokenize (convert from string to list)
    lst_text = nltk.word_tokenize(text)    
    ## remove Stopwords
    if lst_stopwords is not None:
        lst_text = [word for word in lst_text if word not in 
                    lst_stopwords]
                
    ## Stemming (remove -ing, -ly, ...)
    if flg_stemm == True:
        ps = nltk.stem.porter.PorterStemmer()
        lst_text = [ps.stem(word) for word in lst_text]
                
    ## Lemmatisation (convert the word into root word)
    if flg_lemm == True:
        lem = nltk.stem.wordnet.WordNetLemmatizer()
        lst_text = [lem.lemmatize(word) for word in lst_text]
            
    ## back to string from list
    text = " ".join(lst_text)
    
    return text

# %%
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package stopwords to /home/yunfei/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /home/yunfei/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /home/yunfei/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
lst_stopwords = nltk.corpus.stopwords.words("english")

# %%
train_tweetContent["tweet_clean"] = train_tweetContent["tweet"].apply(lambda x: 
          utils_preprocess_text(x, flg_stemm=False, flg_lemm=True, 
          lst_stopwords=lst_stopwords))

dev_tweetContent["tweet_clean"] = dev_tweetContent["tweet"].apply(lambda x: 
          utils_preprocess_text(x, flg_stemm=False, flg_lemm=True, 
          lst_stopwords=lst_stopwords))

test_tweetContent["tweet_clean"] = test_tweetContent["tweet"].apply(lambda x: 
          utils_preprocess_text(x, flg_stemm=False, flg_lemm=True, 
          lst_stopwords=lst_stopwords))

# %%
train_tweetContent
# Out:
#                                                     tweet  \
# 0                                           Watching LOST
# 1                                    @USER_89a3500b i did
# 2       Maneuver so that I can put my team on, hopeful...
# 3       Darko was eating hamburgers in the locker room...
# 4       Girl pack ya bags i'm bout to take you on a ride!
# ...                                                   ...
# 133790  Wow...completely forgot that it's #FollowFrida...
# 133791  Some groovy Texas blues music is playing in my...
# 133792  @USER_8cac2975 Haven't seen that one in ages. ...
# 133793  RT @USER_6d0753d3: You should all go and follo...
# 133794                @USER_4cf8655a Congratulations. (-:
#
#                                               tweet_clean
# 0                                           watching lost
# 1                                           user_89a3500b
# 2           maneuver put team hopefully sooner live dream
# 3       darko eating hamburger locker room played knic...
# 4                      girl pack ya bag im bout take ride
# ...                                                   ...
# 133790  wowcompletely forgot followfriday ahem great p...
# 133791  groovy texas blue music playing head right man...
# 133792          user_8cac2975 havent seen one age remeber
# 133793  rt user_6d0753d3 go follow user_b7a77112 theyr...
# 133794                       user_4cf8655a congratulation
#
# [133795 rows x 2 columns]

# %%
train_tweetContent = train_tweetContent['tweet_clean'].astype(str)
dev_tweetContent = dev_tweetContent['tweet_clean'].astype(str)
test_tweetContent = test_tweetContent['tweet_clean'].astype(str)

# %%
train_tweetContent
# Out:
# 0                                             watching lost
# 1                                             user_89a3500b
# 2             maneuver put team hopefully sooner live dream
# 3         darko eating hamburger locker room played knic...
# 4                        girl pack ya bag im bout take ride
#                                 ...
# 133790    wowcompletely forgot followfriday ahem great p...
# 133791    groovy texas blue music playing head right man...
# 133792            user_8cac2975 havent seen one age remeber
# 133793    rt user_6d0753d3 go follow user_b7a77112 theyr...
# 133794                         user_4cf8655a congratulation
# Name: tweet_clean, Length: 133795, dtype: object

# %%
word_vectorizer = TfidfVectorizer(
        sublinear_tf=True,
        ngram_range=(1, 2),
        min_df=10)
word_vectorizer.fit(train_tweetContent)
tfidf_words = word_vectorizer.get_feature_names()

# %%
tfidf_words
# Out:
# ['00',
#  '09',
#  '0_o',
#  '0n',
#  '10',
#  '10 min',
#  '10 minute',
#  '100',
#  '1000',
#  '10000',
#  '101',
#  '1030',
#  '106',
#  '106 park',
#  '10am',
#  '10th',
#  '11',
#  '112',
#  '1130',
#  '11pm',
#  '11th',
#  '12',
#  '12 club',
#  '12 hour',
#  '120',
#  '1230',
#  '12th',
#  '13',
#  '130',
#  '13th',
#  '14',
#  '140',
#  '140 character',
#  '15',
#  '15 min',
#  '150',
#  '15th',
#  '16',
#  '16 mangoville',
#  '16 pregnant',
#  '17',
#  '18',
#  '188th',
#  '188th jamaica',
#  '18th',
#  '19',
#  '19th',
#  '1st',
#  '1st time',
#  '20',
#  '20 min',
#  '20 minute',
#  '200',
#  '2000',
#  '2009',
#  '2010',
#  '2011',
#  '2012',
#  '2020',
#  '20th',
#  '21',
#  '218',
#  '218 linden',
#  '21st',
#  '22',
#  '22nd',
#  '23',
#  '230',
#  '24',
#  '24 hour',
#  '247',
#  '25',
#  '250',
#  '25th',
#  '26',
#  '26th',
#  '27',
#  '28',
#  '2b',
#  '2day',
#  '2days',
#  '2events1night',
#  '2getha',
#  '2gether',
#  '2hrs',
#  '2k',
#  '2k10',
#  '2mar',
#  '2mm',
#  '2moro',
#  '2morro',
#  '2morrow',
#  '2mrw',
#  '2nd',
#  '2night',
#  '2nite',
#  '2pac',
#  '2pm',
#  '30',
#  '30 min',
#  '30 minute',
#  '300',
#  '3000',
#  '31',
#  '31 next',
#  '313',
#  '313 one',
#  '32',
#  '33',
#  '330',
#  '34',
#  '35',
#  '36',
#  '360',
#  '37',
#  '38',
#  '39',
#  '3am',
#  '3d',
#  '3rd',
#  '40',
#  '400',
#  '41',
#  '42',
#  '43',
#  '430',
#  '44',
#  '45',
#  '45 min',
#  '47',
#  '48',
#  '4am',
#  '4eva',
#  '4get',
#  '4got',
#  '4hrs',
#  '4real',
#  '4rm',
#  '4th',
#  '50',
#  '50 cent',
#  '500',
#  '5000',
#  '52',
#  '530',
#  '54',
#  '55',
#  '56',
#  '57',
#  '5am',
#  '5th',
#  '60',
#  '64',
#  '65',
#  '68',
#  '69',
#  '6am',
#  '6th',
#  '70',
#  '700',
#  '7189514444',
#  '72',
#  '730',
#  '74',
#  '75',
#  '77',
#  '7am',
#  '7pm',
#  '7th',
#  '80',
#  '800',
#  '830',
#  '85',
#  '8am',
#  '8o',
#  '8th',
#  '90',
#  '911',
#  '92',
#  '93',
#  '930',
#  '95',
#  '97',
#  '99',
#  '9am',
#  '9pm',
#  '9th',
#  '__',
#  '___',
#  '____',
#  '_____',
#  '______',
#  'aa',
#  'aaliyah',
#  'aaron',
#  'ab',
#  'abc',
#  'abdc',
#  'abiding',
#  'abiding citizen',
#  'ability',
#  'able',
#  'able see',
#  'absolute',
#  'absolutely',
#  'abt',
#  'abuse',
#  'abyss',
#  'ac',
#  'academy',
#  'acc',
#  'accent',
#  'accept',
#  'accepted',
#  'access',
#  'accident',
#  'accidentally',
#  'accomplish',
#  'accomplished',
#  'according',
#  'account',
#  'accounting',
#  'acct',
#  'ace',
#  'acknowledge',
#  'across',
#  'across street',
#  'act',
#  'act endless',
#  'act like',
#  'actin',
#  'actin like',
#  'acting',
#  'acting like',
#  'action',
#  'active',
#  'activity',
#  'actn',
#  'actor',
#  'actual',
#  'actually',
#  'actually like',
#  'ad',
#  'ada',
#  'adam',
#  'add',
#  'add bbm',
#  'added',
#  'addict',
#  'addicted',
#  'addiction',
#  'adding',
#  'address',
#  'admission',
#  'admission open',
#  'admit',
#  'adorable',
#  'adore',
#  'adores',
#  'adult',
#  'advance',
#  'advantage',
#  'adventure',
#  'advice',
#  'af',
#  'affair',
#  'affect',
#  'afford',
#  'afraid',
#  'africa',
#  'african',
#  'african american',
#  'afta',
#  'afternoon',
#  'afterwards',
#  'age',
#  'agency',
#  'agenda',
#  'agent',
#  'aggressive',
#  'aggy',
#  'ago',
#  'ago lol',
#  'agree',
#  'agreed',
#  'agreed rt',
#  'agreement',
#  'ah',
#  'aha',
#  'ahah',
#  'ahaha',
#  'ahahah',
#  'ahahaha',
#  'ahahahaha',
#  'ahead',
#  'ahh',
#  'ahh man',
#  'ahhh',
#  'ahhhh',
#  'ahhhhh',
#  'ahhhhhh',
#  'ahhhhhhh',
#  'ai',
#  'aid',
#  'aight',
#  'aight im',
#  'aii',
#  'aiight',
#  'aiint',
#  'aim',
#  'aint',
#  'aint da',
#  'aint dat',
#  'aint doin',
#  'aint even',
#  'aint fucking',
#  'aint get',
#  'aint gettin',
#  'aint go',
#  'aint goin',
#  'aint going',
#  'aint gon',
#  'aint gone',
#  'aint good',
#  'aint got',
#  'aint hit',
#  'aint kno',
#  'aint know',
#  'aint lol',
#  'aint mad',
#  'aint neva',
#  'aint never',
#  'aint nobody',
#  'aint nothin',
#  'aint nothing',
#  'aint one',
#  'aint really',
#  'aint right',
#  'aint say',
#  'aint see',
#  'aint seen',
#  'aint shit',
#  'aint shyt',
#  'aint talkin',
#  'aint tell',
#  'aint tryna',
#  'air',
#  'air force',
#  'air sex',
#  'airinhale',
#  'airplane',
#  'airport',
#  'airsex',
#  'aite',
#  'aj',
#  'aja',
#  'ak',
#  'aka',
#  'akas',
#  'akron',
#  'aku',
#  'al',
#  'alarm',
#  'albany',
#  'albert',
#  'album',
#  'alcohol',
#  'alcoholic',
#  'alert',
#  'alex',
#  'ali',
#  'alice',
#  'alice wonderland',
#  'alicia',
#  'alicia key',
#  'alien',
#  'alike',
#  'alil',
#  'alive',
#  'allday',
#  'allen',
#  'allergic',
#  'alley',
#  'alll',
#  'allll',
#  'alllll',
#  'allllll',
#  'allow',
#  'allowed',
#  'allowing',
#  'almost',
#  'almost done',
#  'almost forgot',
#  'alone',
#  'alone lol',
#  'along',
#  'along luv',
#  'alot',
#  'alotta',
#  'alpha',
#  'already',
#  'already got',
#  'already kno',
#  'already know',
#  'already lol',
#  'already told',
#  'alright',
#  'alright im',
#  'alrite',
#  'also',
#  'alter',
#  'although',
#  'always',
#  'always come',
#  'always da',
#  'always end',
#  'always get',
#  'always go',
#  'always good',
#  'always got',
#  'always make',
#  'always say',
#  'always something',
#  'always think',
#  'always wan',
#  'always wanted',
#  'alwayz',
#  'amar250',
#  'amar250 spam',
#  'amaze',
#  'amazed',
#  'amazing',
#  'amazing day',
#  'amazura',
#  'amazura april',
#  'amber',
#  'amc',
#  'amen',
#  'amen rt',
#  'america',
#  'american',
#  'american idol',
#  'americanidol',
#  'amitheonlyone',
#  'amitheonlyone think',
#  'amm',
#  'amor',
#  'amount',
#  'amy',
#  'anatomy',
#  'andd',
#  'anderson',
#  'andor',
#  'andrew',
#  'andthenwehadsex',
#  'angel',
#  'angeles',
#  'anger',
#  'angry',
#  'animal',
#  'anit',
#  'ankle',
#  'annie',
#  'anniversary',
#  'announce',
#  'announcement',
#  'annoy',
#  'annoyed',
#  'annoyin',
#  'annoying',
#  'anonymous',
#  'anotha',
#  'another',
#  'another day',
#  'another earthquake',
#  'another one',
#  'another person',
#  'answer',
#  'answer every',
#  'answer phone',
#  'answer question',
#  'answered',
#  'answering',
#  'ant',
#  'anthem',
#  'anthony',
#  'antonio',
#  'anxious',
#  'any1',
#  'anybody',
#  'anybody else',
#  'anybody know',
#  'anymore',
#  'anymore lol',
#  'anyone',
#  'anyone else',
#  'anyone know',
#  'anyone wan',
#  'anyone want',
#  'anythin',
#  'anything',
#  'anything else',
#  'anything lol',
#  'anything never',
#  'anything worth',
#  'anytime',
#  'anytime soon',
#  'anyway',
#  'anyway lol',
#  'anyways',
#  'anywhere',
#  'anywho',
#  'ap',
#  'apart',
#  'apartment',
#  'ape',
#  'apologize',
#  'apology',
#  'app',
#  'apparently',
#  'appear',
#  'appearance',
#  'appetite',
#  'apple',
#  'applebees',
#  'application',
#  'apply',
#  'appointment',
#  'appreciate',
#  'appreciated',
#  'approach',
#  'approve',
#  'approved',
#  'apps',
#  'appt',
#  'april',
#  'april 16',
#  'april 2nd',
#  'apt',
#  'aqain',
#  'arab',
#  'ard',
#  'area',
#  'aree',
#  'arent',
#  'argue',
#  'arguing',
#  'argument',
#  'aries',
#  'arizona',
#  'arm',
#  'army',
#  'around',
#  'around corner',
#  'around like',
#  'around lol',
#  'around ur',
#  'arrested',
#  'arrive',
#  'arrived',
#  'arrogant',
#  'art',
#  'artest',
#  'article',
#  'artist',
#  'arty',
#  'as',
#  'as back',
#  'as beat',
#  'as bed',
#  'as big',
#  'as bitch',
#  'as class',
#  'as day',
#  'as dont',
#  'as fuck',
#  'as get',
#  'as girl',
#  'as got',
#  'as hell',
#  'as home',
#  'as im',
#  'as kid',
#  'as like',
#  'as lmao',
#  'as lol',
#  'as man',
#  'as need',
#  'as nigga',
#  'as ppl',
#  'as rt',
#  'as shit',
#  'as sleep',
#  'asap',
#  'ash',
#  'ashamed',
#  'ashley',
#  'ashy',
#  'asian',
#  'aside',
#  'ask',
#  'ask im',
#  'ask question',
#  'askd',
#  'asked',
#  'askin',
#  'asking',
#  'askn',
#  'asks',
#  'asleep',
#  'ass',
#  'asshole',
#  'assistant',
#  'associate',
#  'assume',
#  'assuming',
#  'ate',
#  'atl',
#  'atlanta',
#  'atlantic',
#  'atleast',
#  'atm',
#  'att',
#  'attached',
#  'attack',
#  'attacked',
#  'attempt',
#  'attend',
#  'attendance',
#  'attention',
#  'attitude',
#  'attn',
#  'attracted',
#  'attractive',
#  'attracts',
#  'audio',
#  'audition',
#  'aug',
#  'august',
#  'aunt',
#  'auntie',
#  'austin',
#  'automatic',
#  'automatically',
#  'autotune',
#  'available',
#  'avatar',
#  'ave',
#  'ave queen',
#  'avenue',
#  'average',
#  'avi',
#  'avoid',
#  'aw',
#  'awake',
#  'award',
#  'aware',
#  'away',
#  'away biggest',
#  'away lol',
#  'awe',
#  'awesome',
#  'awhile',
#  'awkward',
#  'awsome',
#  'aww',
#  'aww man',
#  'aww poor',
#  'aww thanks',
#  'aww well',
#  'awww',
#  'awww man',
#  'awww thanks',
#  'awwww',
#  'awwwww',
#  'awwwwww',
#  'ay',
#  'aye',
#  'ayee',
#  'ayeee',
#  'ayeeee',
#  'ayo',
#  'ayoo',
#  'ayy',
#  'az',
#  'azz',
#  'b4',
#  'b4 12',
#  'b4 go',
#  'babe',
#  'babe rt',
#  'babez',
#  'baby',
#  'baby daddy',
#  'baby girl',
#  'baby im',
#  'baby lol',
#  'baby love',
#  'baby mama',
#  'baby momma',
#  'baby shower',
#  'babygirl',
#  'babyy',
#  'babyyy',
#  'bac',
#  'bacc',
#  'bachelor',
#  'back',
#  'back back',
#  'back bed',
#  'back cuz',
#  'back da',
#  'back day',
#  'back dont',
#  'back forth',
#  'back good',
#  'back got',
#  'back head',
#  'back home',
#  'back hurt',
#  'back im',
#  'back like',
#  'back lol',
#  'back rt',
#  'back school',
#  'back sleep',
#  'back tho',
#  'back time',
#  'back work',
#  'background',
#  'background pic',
#  'backk',
#  'backup',
#  'backwards',
#  'backyard',
#  'bacon',
#  'bacon egg',
#  'bad',
#  'bad as',
#  'bad bitch',
#  'bad boy',
#  'bad day',
#  'bad girl',
#  'bad im',
#  'bad lol',
#  'bad romance',
#  'bad thing',
#  'badass',
#  'badd',
#  'baddd',
#  'badder',
#  'baddest',
#  'badgirlsclub',
#  'badly',
#  'badu',
#  'bae',
#  'bag',
#  'bagel',
#  'baggy',
#  'bahaha',
#  'bahahaha',
#  'bahahahaha',
#  'bailey',
#  'bak',
#  'bake',
#  'baked',
#  'baker',
#  'bakk',
#  'balance',
#  'bald',
#  'ball',
#  'baller',
#  'ballin',
#  'balling',
#  'balloon',
#  'baltimore',
#  'bam',
#  'banana',
#  'band',
#  'bang',
#  'bang bang',
#  'banger',
#  'bangin',
#  'banging',
#  'bank',
#  'bap',
#  'baq',
#  'baqk',
#  'baqq',
#  'bar',
#  'bar 12',
#  'barber',
#  'barber shop',
#  'barbershop',
#  'barbie',
#  'barbies',
#  'bare',
#  'barely',
#  'bark',
#  'barnes',
#  'bartender',
#  'base',
#  'baseball',
#  'based',
#  'basement',
#  'bash',
#  'basic',
#  'basic bitch',
#  'basically',
#  'basis',
#  'basket',
#  'basketball',
#  'basketball game',
#  'basketball team',
#  'bass',
#  'bastard',
#  'bat',
#  'bath',
#  'bathe',
#  'bathing',
#  'bathroom',
#  'batman',
#  'battery',
#  'battle',
#  'bay',
#  'bb',
#  'bball',
#  'bbl',
#  'bbm',
#  'bbm contact',
#  'bbm lol',
#  'bbm pin',
#  'bbms',
#  'bbq',
#  'bbqs',
#  'bby',
#  'bc',
#  'bc im',
#  'bck',
#  'bcuz',
#  'bd',
#  'bday',
#  'bday bash',
#  'bday party',
#  'beach',
#  'beamer',
#  'beamer benz',
#  'bean',
#  'bear',
#  'bear fan',
#  'beard',
#  'beasley',
#  'beast',
#  'beat',
#  'beat as',
#  'beat yo',
#  'beater',
#  'beatin',
#  'beating',
#  'beautiful',
#  'beautiful day',
#  'beautiful girl',
#  'beautiful lie',
#  'beautiful outside',
#  'beautiful woman',
#  'beauty',
#  'became',
#  'becky',
#  'become',
#  'becomes',
#  'becomes habit',
#  'becoming',
#  'becuz',
#  'bed',
#  'bed early',
#  'bed get',
#  'bed im',
#  'bed like',
#  'bed lol',
#  'bed time',
#  'bedroom',
#  'bedtime',
#  'bee',
#  'beef',
#  'beer',
#  'beforeidie',
#  'beforeidie wan',
#  'beforeidie want',
#  'beg',
#  'begging',
#  'begin',
#  'beginning',
#  'behave',
#  'behavior',
#  'behind',
#  'beiber',
#  'bein',
#  'bein mean',
#  'belief',
#  'believe',
#  'believe im',
#  'believed',
#  'believer',
#  'bell',
#  'belly',
#  'belong',
#  'belt',
#  'ben',
#  'bench',
#  'bend',
#  'benefit',
#  'benjamin',
#  'bent',
#  'bentley',
#  'bently',
#  'benz',
#  'benz bentley',
#  'berry',
#  'beside',
#  'besides',
#  'best',
#  'best believe',
#  'best ever',
#  'best friend',
#  'best lol',
#  'best thing',
#  'best time',
#  'best way',
#  'bestest',
#  'bestfriend',
#  'bestie',
#  'besties',
#  'bet',
#  'bet lol',
#  'beta',
#  'betmessedupwhen',
#  'betmessedupwhen got',
#  'betta',
#  'betta den',
#  'betta stop',
#  'better',
#  'better get',
#  'better im',
#  'better lol',
#  'better soon',
#  'better stop',
#  'better tell',
#  'better watch',
#  'better yet',
#  'betty',
#  'beware',
#  'bey',
#  'beyonce',
#  'beyond',
#  'bf',
#  'bff',
#  'bg',
#  'bgc',
#  'bgt',
#  'bh',
#  'bi',
#  'bias',
#  'bible',
#  'bible study',
#  'biddy',
#  'bieber',
#  'bien',
#  'big',
#  'big as',
#  'big booty',
#  'big bro',
#  'big deal',
#  'big dick',
#  'big enough',
#  'big girl',
#  'big head',
#  'big homie',
#  'big si',
#  'big thing',
#  'big time',
#  'big ups',
#  'bigger',
#  'biggest',
#  'biggest party',
#  'biggie',
#  'bighead',
#  'bike',
#  'bikini',
#  'bill',
#  'billion',
#  'billy',
#  'bin',
#  'bingo',
#  'bio',
#  'bipolar',
#  'biq',
#  'bird',
#  'birdman',
#  'birth',
#  'birth control',
#  ...]

# %%
f = open('tfidf-words','w')
f.write('tfidf words ' + '\n')
for word in tfidf_words:
    f.write(word + '\n')
f.close()
print('save tfidf words successfully')
# Out:
# save tfidf words successfully

# %%
train_features = word_vectorizer.transform(train_tweetContent)
dev_features   = word_vectorizer.transform(dev_tweetContent)
test_features  = word_vectorizer.transform(test_tweetContent)

# %%
train_features.get_shape()
# Out:
# (133795, 12422)

# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn import metrics

clf = MultinomialNB().fit(train_features, train_labels)
predicted_labels = clf.predict(dev_features)

accuracy = metrics.accuracy_score(dev_labels, predicted_labels)
print('Accuracy：', '%.4f' % accuracy)
# Out:
# Accuracy： 0.4563

# %%
from sklearn.linear_model import LogisticRegression

clf = LogisticRegression(max_iter=5000, n_jobs=-1).fit(train_features, train_labels)
predicted_labels = clf.predict(dev_features)

accuracy = metrics.accuracy_score(dev_labels, predicted_labels)
print('Accuracy：', '%.4f' % accuracy)
# Out:
# Accuracy： 0.4476

# %%
from sklearn.ensemble import RandomForestClassifier

clf = RandomForestClassifier(max_depth=100, random_state=0, n_jobs=-1).fit(train_features, train_labels)
predicted_labels = clf.predict(dev_features)

accuracy = metrics.accuracy_score(dev_labels, predicted_labels)
print('Accuracy：', '%.4f' % accuracy)
# Out:
# Accuracy： 0.4407

# %% [markdown]
# ## Word2Vec

# %%
# Train your own Word2Vec model using your own text corpus
list_of_tweets=[]
for tweet in train_tweetContent:
    list_of_tweets.append(tweet.split())

# %%
list_of_tweets
# Out:
# [['watching', 'lost'],
#  ['user_89a3500b'],
#  ['maneuver', 'put', 'team', 'hopefully', 'sooner', 'live', 'dream'],
#  ['darko', 'eating', 'hamburger', 'locker', 'room', 'played', 'knicks', 'lol'],
#  ['girl', 'pack', 'ya', 'bag', 'im', 'bout', 'take', 'ride'],
#  ['user_a9cf8f82', 'lol', 'yeah', 'check', 'bro'],
#  ['rt',
#   'user_5eae722d',
#   'inhighschool',
#   'mr',
#   'stavisky',
#   'dnt',
#   'lk',
#   'breath',
#   'smelled',
#   'lk',
#   'straight',
#   'as',
#   'lmao',
#   'use',
#   '2',
#   'chase',
#   'u',
#   'dn',
#   'hall'],
#  ['inhighschool',
#   'trenton',
#   'high',
#   'girl',
#   'basketball',
#   'team',
#   'always',
#   'best',
#   'record',
#   'highschool',
#   'sport',
#   'team',
#   'nothing',
#   'changed'],
#  ['cheerleading', 'team', 'need', 'mr', 'grady', 'back'],
#  ['girl', 'ashley', 'hines', 'beast', 'cant', 'stop'],
#  ['da',
#   'high',
#   'always',
#   'best',
#   'fan',
#   'going',
#   'way',
#   'back',
#   'inhighschool'],
#  ['rip', 'jack', 'daniel', 'burger'],
#  ['user_43aad9dc',
#   'oh',
#   'shes',
#   'back',
#   'look',
#   'like',
#   'life',
#   'hit',
#   'hard',
#   'im',
#   'bout',
#   'approach',
#   'caution',
#   'cheer',
#   'babe',
#   'sound'],
#  ['liquor', 'make', 'feel'],
#  ['credit',
#   'union',
#   'need',
#   'hurry',
#   'get',
#   'repaired',
#   'reopen',
#   'ewing',
#   'line',
#   'crazy',
#   'long',
#   'pause'],
#  ['looking', 'new', 'dj', 'squad'],
#  ['rt',
#   'user_1ec848f9',
#   'rt',
#   'user_6197f95d',
#   'looking',
#   'new',
#   'dj',
#   'squadon',
#   'good',
#   'look',
#   'laylei',
#   'need',
#   'permanent',
#   'one'],
#  ['hello', 'world'],
#  ['rt',
#   'user_a9cf8f82',
#   'user_2f81238c',
#   'whole',
#   'crew',
#   'make',
#   'since',
#   'lol'],
#  ['user_6bd290f1', 'yo', 'look', 'bub', 'luv', 'babysitting'],
#  ['jluv', 'said', 'freezer', '4', 'month'],
#  ['rt', 'user_52987190', 'user_6197f95d', 'wheres', 'abyss', 'party'],
#  ['user_6bd290f1', 'uncle', 'dj', 'going'],
#  ['nowplaying', 'bub', 'luv', 'see', 'mad', 'light'],
#  ['funk',
#   'flex',
#   'isnt',
#   'abyss',
#   'wtf',
#   'seen',
#   'somebody',
#   'saif',
#   'yo',
#   'u',
#   'cousin',
#   'problem',
#   'ill',
#   'sove',
#   'em',
#   'beware',
#   'hater'],
#  ['everybody', 'dread', 'abyss', 'truestory'],
#  ['ralphmarston',
#   'mere',
#   'opinion',
#   'someone',
#   'else',
#   'power',
#   'hold',
#   'back'],
#  ['doniquecperez',
#   'others',
#   'start',
#   'engaging',
#   'gossip',
#   'walk',
#   'away',
#   'dont',
#   'part',
#   'rumor'],
#  ['revrunwisdom',
#   'u',
#   'move',
#   'fwd',
#   'flinching',
#   'str8',
#   'ahead',
#   'day',
#   'day',
#   'door',
#   'open',
#   'continue',
#   '2',
#   'open',
#   'da',
#   'nex',
#   '1'],
#  ['revrunwisdom', 'im', 'warrior', 'worrier', 'power', 'thought'],
#  ['ralphmarston',
#   'rejoice',
#   'good',
#   'fortune',
#   'others',
#   'use',
#   'source',
#   'inspiration',
#   'reason',
#   'expressing',
#   'gratitude'],
#  ['revrunwisdom',
#   'wan',
#   'na',
#   'peaceful',
#   'day',
#   'avoid',
#   'fool',
#   'ur',
#   'might',
#   'u',
#   'dont',
#   'answer',
#   'every',
#   'call',
#   'ya',
#   'know'],
#  ['drthema',
#   'people',
#   'want',
#   'attention',
#   'even',
#   'negative',
#   'dont',
#   'get',
#   'caught',
#   'hype'],
#  ['doniquecperez',
#   'any1',
#   'rise',
#   'abve',
#   'situation',
#   'want',
#   '2',
#   'dont',
#   'sink',
#   'selfpity',
#   'distorts',
#   '1',
#   'mindmesses',
#   'ur',
#   'chance'],
#  ['revrunwisdom',
#   'everything',
#   'life',
#   'want',
#   'give',
#   'enough',
#   'ppl',
#   'life',
#   'want',
#   'ziglar',
#   'user_5400c2af'],
#  ['revrunwisdom',
#   'u',
#   'feel',
#   'ok',
#   'come',
#   'second',
#   'thats',
#   'exactly',
#   'happens',
#   'life',
#   'kennedy'],
#  ['ralphmarston', 'feel', 'reality', 'already', 'enough', 'magnificent'],
#  ['revrunwisdom',
#   'lady',
#   'never',
#   'let',
#   'heart',
#   'cause',
#   'forget',
#   'protect',
#   'whats',
#   'left',
#   'u'],
#  ['doniquecperez',
#   'r',
#   'time',
#   'u',
#   'must',
#   'close',
#   'heart',
#   '2',
#   'bitter',
#   'feeling',
#   'devour',
#   'u',
#   'even',
#   'though',
#   'person',
#   'caused',
#   'one'],
#  ['revrunwisdom',
#   'love',
#   'act',
#   'endless',
#   'forgiveness',
#   'tender',
#   'look',
#   'ur',
#   'mate',
#   'becomes',
#   'habit'],
#  ['drthema', 'let', 'hope', 'outweigh', 'fear', 'move', 'toward', 'dream'],
#  ['doniquecperez',
#   'help',
#   'someone',
#   'needed',
#   'help',
#   'desparately',
#   'dont',
#   'talkbragboast',
#   'friend',
#   'heart'],
#  ['doniquecperez',
#   'dont',
#   'get',
#   'discouraged',
#   'moved',
#   'someone',
#   'perception',
#   'opinion'],
#  ['revrunwisdom',
#   'perfectionism',
#   'self',
#   'abuse',
#   'highest',
#   'degree',
#   'eveything',
#   'right',
#   'something',
#   'aint'],
#  ['drthema',
#   'word',
#   'give',
#   'thing',
#   'power',
#   'speak',
#   'life',
#   'destructive',
#   'thought',
#   'future'],
#  ['ralphmarston', 'way', 'see', 'becomes', 'way', 'make', 'see'],
#  ['doniquecperez',
#   'see',
#   'door',
#   'opened',
#   'u',
#   'walk',
#   'right',
#   'lock',
#   '1',
#   'u',
#   'walked',
#   'path',
#   'clea'],
#  ['kirkfranklin',
#   'landed',
#   'feel',
#   'like',
#   'talking',
#   'whatever',
#   'mountain',
#   'u',
#   'life',
#   'right',
#   'drug',
#   'depression',
#   'divorce',
#   'moneyjust'],
#  ['revrunwisdom',
#   'lord',
#   'shepherd',
#   'shall',
#   'want',
#   'morning',
#   'meditation'],
#  ['revrunwisdom',
#   'many',
#   'couple',
#   'mistakenly',
#   'plan',
#   'fairy',
#   'tale',
#   'wedding',
#   'real',
#   'focus',
#   'fairy',
#   'tale',
#   'life',
#   '2gether'],
#  ['drthema',
#   'beat',
#   'blue',
#   'counting',
#   'blessing',
#   'thing',
#   'may',
#   'perfect',
#   'still',
#   'blessed'],
#  ['ralphmarston',
#   'person',
#   'becoming',
#   'always',
#   'watching',
#   'person',
#   'right'],
#  ['revrunwisdom',
#   'greed',
#   'greed',
#   'ur',
#   'foolishly',
#   'competitive',
#   'never',
#   'satisfied',
#   'gottakeepitincheck'],
#  ['revrunwisdom',
#   'u',
#   'want',
#   'others',
#   'happy',
#   'practice',
#   'compassion',
#   'u',
#   'want',
#   'happy',
#   'practice',
#   'compassion'],
#  ['ralphmarston',
#   'going',
#   'get',
#   'difficult',
#   'dont',
#   'waste',
#   'time',
#   'looking',
#   '4',
#   'way',
#   '2',
#   'complainget',
#   'busy',
#   'finding',
#   'real',
#   'workable',
#   'way',
#   '2',
#   'make',
#   'thin'],
#  ['drthema',
#   'something',
#   'today',
#   'feed',
#   'spirit',
#   'empowers',
#   'start',
#   'week',
#   'higher',
#   'place'],
#  ['drthema',
#   'memory',
#   'moment',
#   'recorded',
#   'eternity',
#   'mindful',
#   'u',
#   'spend',
#   'moment'],
#  ['preworkout', 'prep', 'begun'],
#  ['really',
#   'dont',
#   'like',
#   'college',
#   'fb',
#   'player',
#   'onfield',
#   'production',
#   'negated',
#   'single',
#   'workout',
#   'proof',
#   'pudding'],
#  ['user_b7cdabe3',
#   'people',
#   'dont',
#   'dance',
#   'like',
#   'get',
#   'burn',
#   'anymore',
#   'frowned',
#   'uponlol'],
#  ['rt',
#   'user_9c9e75e2',
#   'officially',
#   'getting',
#   'rid',
#   'iphone',
#   'dysfunctional',
#   'button',
#   'weekendget',
#   '9700',
#   'blackertheberrythesweetertheuse'],
#  ['rt',
#   'user_9c9e75e2',
#   'user_8d0e8566',
#   'think',
#   'thats',
#   'movemake',
#   'happen',
#   'play',
#   'word',
#   'mole'],
#  ['user_b7cdabe3', 'oh', 'okay'],
#  ['next',
#   '2hrs',
#   'tweet',
#   'user_fe579e73',
#   'gibing',
#   'idea',
#   'theory',
#   'tweet'],
#  ['user_fe579e73', 'u', 'change', 'ur', 'setting', 'use', 'twitlonger'],
#  ['rt',
#   'user_de057bc2',
#   'twitter',
#   'jacked',
#   'tonightjust',
#   'iphones',
#   'blackertheberrythesweetertheuse'],
#  ['rt',
#   'user_de057bc2',
#   'user_8d0e8566',
#   'eff',
#   'yo',
#   'blackberrysore',
#   'loser'],
#  ['user_45b5c066',
#   'user_2b5b12ff',
#   'body',
#   'nice',
#   'contest',
#   'bukket',
#   'nekked'],
#  ['peterwisdom',
#   'u',
#   'wake',
#   'ur',
#   'gal',
#   'gal',
#   'ur',
#   'bed',
#   'staring',
#   'utake',
#   'solace',
#   'knowing',
#   'shell',
#   'sleep',
#   'u',
#   'escape',
#   'lol'],
#  ['user_b7cdabe3', 'lol'],
#  ['rt',
#   'user_45b5c066',
#   'familyguy',
#   'meg',
#   'brian',
#   'make',
#   'meg',
#   'stalk',
#   'like',
#   'misery',
#   'ltlt',
#   'u',
#   'use',
#   'shag',
#   'blog',
#   'term',
#   'classicdid'],
#  ['rt',
#   'user_9c9e75e2',
#   'user_8d0e8566',
#   'whatttttt',
#   'convo',
#   'lollol',
#   'blackstreet',
#   'sings',
#   'dont',
#   'leave',
#   'dont',
#   'leeeeave',
#   'giirrl',
#   'lol'],
#  ['listening', 'mgmt', 'station', 'pandora'],
#  ['rt',
#   'user_b7cdabe3',
#   'user_8d0e8566',
#   'lol',
#   'im',
#   'serious',
#   'n',
#   'e',
#   'way',
#   'diggin',
#   'new',
#   'avatarthanks'],
#  ['user_b7cdabe3', 'hear', 'u'],
#  ['rt',
#   'user_60a93820',
#   'rt',
#   'user_6b117f67',
#   'dinner',
#   'sake',
#   'cafe',
#   'last',
#   'night',
#   'nola',
#   'friendslt',
#   'going',
#   'againstalkerrt'],
#  ['user_60a93820', 'user_de057bc2', 'lol'],
#  ['start', 'sneezing', 'im', 'tearing', 'user_de057bc2', 'new', 'one', 'see'],
#  ['rt',
#   'user_4ece06e4',
#   'user_8d0e8566',
#   'keep',
#   'ur',
#   'profile',
#   'public',
#   'gained',
#   '700',
#   'follower',
#   'since',
#   'decemberwill'],
#  ['rt',
#   'user_8fc53fde',
#   'need',
#   'doctor',
#   'visit',
#   'home',
#   'app',
#   'spoken',
#   'w',
#   'vlingodo',
#   'u',
#   'like',
#   'vlingo',
#   'didnt',
#   'feel',
#   'comfortable',
#   'wit'],
#  ['rt',
#   'user_36348514',
#   'man',
#   'day',
#   'starting',
#   'baddont',
#   'let',
#   'ur',
#   'day',
#   'suck',
#   '8am'],
#  ['user_8fc53fde', 'c', 'watching', 'doctor', 'u'],
#  ['letsbereal', 'techno', 'go', 'hard', 'remixing', 'popular', 'rap', 'song'],
#  ['salsa',
#   'merengue',
#   'hiphop',
#   'throwback',
#   'indie',
#   'house',
#   'samba',
#   'mashups',
#   'booty',
#   'bounce',
#   'bailefunk',
#   'bhangra',
#   'arabic',
#   'reggaeton',
#   'reggae',
#   'dancehall'],
#  ['letsbereal',
#   'wasnt',
#   'smartphones',
#   'like',
#   'bb9700',
#   'id',
#   'bored',
#   'work',
#   'damn',
#   'beautiful',
#   'outside'],
#  ['rt',
#   'user_9c9e75e2',
#   'user_8d0e8566',
#   'lol',
#   'still',
#   'ipod',
#   'one',
#   'big',
#   'embarassing',
#   'mix',
#   'messhaving',
#   'eclectic',
#   'musical',
#   'taste',
#   'keep',
#   'thing',
#   'interesting'],
#  ['nowplaying', 'working', 'day', 'night', 'mj'],
#  ['letsbereal',
#   'user_a400b1fb',
#   'trina',
#   'need',
#   'song',
#   'video',
#   'together',
#   'resurrect',
#   'bet',
#   'dark',
#   'make',
#   'happen',
#   'montebellotuttifruity'],
#  ['user_9c9e75e2', 'vanity', 'last', 'dragon', 'right'],
#  ['rt',
#   'user_0a66c761',
#   'random',
#   'numba',
#   'txt',
#   'asking',
#   'color',
#   'panty',
#   'onwtfnormally',
#   'u',
#   'answering',
#   'mean',
#   'ur',
#   'wearing',
#   'ne'],
#  ['nowplaying', 'blame', 'boogie', 'jackson', 'mainly', 'mike', 'tho', 'lol'],
#  ['rt',
#   'user_8fc53fde',
#   'user_8d0e8566',
#   'probably',
#   'jerk',
#   'would',
#   'groundits',
#   'sambon',
#   'anyway',
#   'lol'],
#  ['rt',
#   'user_5566e760',
#   'user_8d0e8566',
#   'lol',
#   'ur',
#   'funny',
#   'hahahalol',
#   'u',
#   'looked',
#   'mobile',
#   'huh',
#   'like',
#   'text',
#   'talk',
#   'mobile'],
#  ['rt',
#   'user_36348514',
#   'great',
#   'morning',
#   'peep',
#   'friday',
#   'arent',
#   'u',
#   'excited',
#   'yes'],
#  ['rt',
#   'user_45359724',
#   'user_8d0e8566',
#   'heard',
#   'say',
#   'ahh',
#   'thought',
#   'haha',
#   'stuck',
#   'ur',
#   'headthanks',
#   'pressing',
#   'play',
#   'song',
#   'head'],
#  ['rt',
#   'user_abc6f6bb',
#   'good',
#   'morning',
#   'pray',
#   'good',
#   'test',
#   'morningu',
#   'begin',
#   'weekend'],
#  ['ff',
#   'user_60a93820',
#   'user_80e6e420',
#   'user_7e539845',
#   'user_0b377a77',
#   'user_abc6f6bb',
#   'user_d7ee1e1d',
#   'user_0a66c761',
#   'user_6868525f',
#   'user_cf5bdbf9'],
#  ['rt',
#   'user_17ca9f7f',
#   'user_8d0e8566',
#   'lol',
#   'switch',
#   'pete',
#   'whats',
#   'good',
#   'mani',
#   'forgot',
#   'saw',
#   'change',
#   'ubertwitter',
#   'isnt',
#   'listing',
#   'yet'],
#  ['user_17ca9f7f', 'im', 'good', 'though', 'howd', 'bball', 'action', 'turn'],
#  ['user_bc09b57d', 'yeah', 'know'],
#  ['lol',
#   'see',
#   'martial',
#   'art',
#   'master',
#   'never',
#   'return',
#   'anger',
#   'kuhai',
#   'even',
#   'battle',
#   'u',
#   'hope',
#   'learned',
#   'lesson'],
#  ['ibelieve',
#   'u',
#   'get',
#   'angry',
#   'uve',
#   'already',
#   'loss',
#   'battle',
#   'wit',
#   'need',
#   'focus',
#   'calm',
#   'mind'],
#  ['rt',
#   'user_4ece06e4',
#   'user_8d0e8566',
#   'one',
#   'class',
#   'yaye',
#   'favorite',
#   'day',
#   'week',
#   'good',
#   'living',
#   'im',
#   '1130'],
#  ['user_96b3938e',
#   'cant',
#   'remember',
#   'one',
#   'saw',
#   'best',
#   'pride',
#   'last',
#   'month'],
#  ['ibelieve',
#   '9',
#   '10',
#   'woman',
#   'would',
#   'agree',
#   'placesiwannahavesex',
#   'would',
#   'include',
#   'rain',
#   'ex',
#   'miami',
#   'beach',
#   'rain'],
#  ['rt',
#   'user_45359724',
#   'user_8d0e8566',
#   'hahaha',
#   'girl',
#   'skirt',
#   'panty',
#   'would',
#   'help',
#   'lt',
#   'prep',
#   'time',
#   'shave',
#   '1',
#   'second'],
#  ['rt',
#   'user_4ece06e4',
#   'lol',
#   'didnt',
#   'tell',
#   'u',
#   'pda',
#   'maybe',
#   'private',
#   'jet13',
#   'tint',
#   'isnt',
#   'pda',
#   'ur',
#   'referring',
#   'private',
#   'public'],
#  ['rt',
#   'user_b817d0d4',
#   'bullsht',
#   'put',
#   '20',
#   'worth',
#   'gas',
#   'truck',
#   'got',
#   'quarter',
#   'tank',
#   'fulllol',
#   'u',
#   'got',
#   'robbed'],
#  ['dang', 'another', 'democratic', 'seat', 'come', 'open'],
#  ['rt',
#   'user_2e0397cb',
#   'followgt',
#   'pretty',
#   'user_46c0f9f4',
#   'followfridaynow',
#   'following'],
#  ['rt',
#   'user_46c0f9f4',
#   'wheres',
#   'new',
#   'followersputting',
#   'cd',
#   'cd',
#   'book'],
#  ['rt',
#   'user_fe579e73',
#   'user_8d0e8566',
#   'tracking',
#   '1z3r4wfollowed',
#   '1000',
#   'digitslol',
#   'need',
#   'psf',
#   'extra',
#   'packing',
#   'added',
#   'please'],
#  ['inspection', 'done', 'ballys'],
#  ['u',
#   'need',
#   'inspection',
#   'sticker',
#   'youre',
#   'sherwood',
#   'forest',
#   'area',
#   'hit',
#   'shell',
#   'gas',
#   'station',
#   'cane',
#   'pizza',
#   'hut',
#   'referral'],
#  ['workoutcredos',
#   'looong',
#   'time',
#   'comiiing',
#   'u',
#   'knoooooooooww',
#   'change',
#   'gon',
#   'come',
#   'ooooohh',
#   'yes',
#   'wiiiiilllll'],
#  ['shawty',
#   'u',
#   'know',
#   'got',
#   'cash',
#   'uuuu',
#   'dont',
#   'even',
#   'ask',
#   'anything',
#   'u',
#   'want',
#   'cuz',
#   'make',
#   'rain',
#   'uif',
#   'u',
#   'gflol'],
#  ['finish',
#   'subway',
#   'sandwich',
#   'find',
#   'reason',
#   'go',
#   'outside',
#   'ill',
#   'hit',
#   'mall',
#   'new',
#   'rubberband',
#   'wristband'],
#  ['user_9c9e75e2', 'travelingh', 'work', 'deductible', 'help', 'alot'],
#  ['rt', 'user_45b5c066', 'user_8d0e8566', 'convostoryahh', 'pti'],
#  ['may',
#   'ride',
#   'parade',
#   'ground',
#   'someone',
#   'fb',
#   'said',
#   'there',
#   'college',
#   'family',
#   'reunionim',
#   'bored',
#   'enough',
#   'check'],
#  ['user_611b2a4f',
#   'alright',
#   'im',
#   'big',
#   'buck',
#   'whammy',
#   'big',
#   'buck',
#   'whammy',
#   'stop',
#   'host',
#   'win',
#   'free',
#   'bottle',
#   'seraphin',
#   'bizarromaker'],
#  ['dont',
#   'feel',
#   'fire',
#   'coming',
#   'unc',
#   'reiatsu',
#   'tame',
#   'guard',
#   'weak',
#   'minded',
#   'hate',
#   'player',
#   'passion',
#   'couldnt',
#   'play',
#   '4'],
#  ['sorry', 'guard', 'strickland', 'come', 'play'],
#  ['ufc', 'best', '2009', 'spike', 'hughes', 'v', 'serra'],
#  ['rt',
#   'user_b817d0d4',
#   'keep',
#   'stabbing',
#   'back',
#   'quit',
#   'handing',
#   'knifeor',
#   'pay',
#   'attention',
#   'u',
#   'see',
#   'coming'],
#  ['observation',
#   'person',
#   'close',
#   'eye',
#   'people',
#   'party',
#   'normally',
#   'person',
#   'fun'],
#  ['rt', 'user_46c0f9f4', 'good', 'mornn', 'good', 'morning'],
#  ['observation',
#   'actually',
#   'workout',
#   'discipline',
#   'im',
#   'aloneand',
#   'really',
#   'fine',
#   'female',
#   'proximity'],
#  ['best',
#   'observation',
#   'noticing',
#   'transformation',
#   'body',
#   'working',
#   'still',
#   'long',
#   'way',
#   'go'],
#  ['rt',
#   'user_e862798a',
#   'fact',
#   'lot',
#   'basic',
#   'bitch',
#   'party',
#   'last',
#   'night',
#   'helped',
#   'diamond',
#   'stand',
#   'out1st',
#   'block',
#   '3rd',
#   'st',
#   'looked',
#   'like',
#   'bourbon',
#   'let'],
#  ['observation',
#   'got',
#   'hug',
#   'day',
#   'wed',
#   'happier',
#   'people',
#   'user_5aac9e88',
#   'dont',
#   'u',
#   'agree'],
#  ['mj', 'making', 'album', 'tour'],
#  ['reminiscing',
#   'hard',
#   'paint',
#   'basketball',
#   'game',
#   'rec',
#   'center',
#   'went',
#   'hear',
#   'game',
#   'horrible',
#   'court',
#   'look',
#   'gr8'],
#  ['reminiscing',
#   'day',
#   'nemesis',
#   'bates',
#   'threw',
#   'piss',
#   'chick',
#   'face',
#   'quad',
#   'realest',
#   'f',
#   'u',
#   'moment',
#   'lsu',
#   'history'],
#  ['reminiscing',
#   'wild',
#   'stuff',
#   'senior',
#   'yeari',
#   'sober',
#   'didnt',
#   'start',
#   'drinking',
#   'til',
#   'age',
#   '2223'],
#  ['reminiscing',
#   'cdub',
#   'shot',
#   'free',
#   'throwmissed',
#   'caught',
#   'rim',
#   'george',
#   'head',
#   'alltimegreatrecbballmoment'],
#  ['reminiscing',
#   'term',
#   'sack',
#   'chaser',
#   'coined',
#   'heauxs',
#   'coming',
#   'rec',
#   '2',
#   'c',
#   'master',
#   'p',
#   'crew',
#   'workout',
#   'sit',
#   'watch'],
#  ['reminiscing',
#   '1st',
#   'time',
#   'met',
#   'sister',
#   'user_de057bc2',
#   'let',
#   'tell',
#   'u',
#   'asshole',
#   'say',
#   'answered',
#   'questionmy',
#   'way',
#   'lol'],
#  ['judge', 'hard', 'year'],
#  ['user_20c15b69'],
#  ['user_21fe08ea',
#   'aww',
#   'suck',
#   'ya',
#   'dont',
#   'mind',
#   'asking',
#   'whats',
#   'ruining',
#   'relationship'],
#  ['might',
#   'take',
#   'little',
#   'twitter',
#   'absence',
#   'debating',
#   'whether',
#   'sure',
#   'yet'],
#  ['user_7b0344f9',
#   'ha',
#   'ubertwitter',
#   'tweet',
#   'alittle',
#   'behind',
#   'sometimes'],
#  ['irefuseto', 'let', 'people', 'walk', 'give', 'stop', 'believing', 'stand'],
#  ['goodbye'],
#  ['user_f214f7df',
#   'joined',
#   'denny',
#   'kasey',
#   'team',
#   'kyle',
#   'pic',
#   'making',
#   'sick'],
#  ['user_f214f7df', 'dont', 'got', 'ta', 'get', 'shitty'],
#  ['user_115ebd75',
#   'listen',
#   'every',
#   'tuesday',
#   'thursday',
#   'talk',
#   'chat',
#   'room',
#   'everyone',
#   'really',
#   'nice'],
#  ['user_3af8bff1', 'yea', 'thank', 'looking', 'everywhere', 'find', 'racing'],
#  ['user_955141d0', 'hahaha'],
#  ['ur', 'gon', 'na', 'meet', 'anywhere'],
#  ['user_f214f7df', 'got', '2009', 'one', 'signed', 'user_25f2ef26', 'met'],
#  ['ur', 'as'],
#  ['time', 'wwe', 'superstar', 'wheres', 'user_f59c08df'],
#  ['hbk', 'dvd', 'got', 'ta', 'buy'],
#  ['damn', 'pretty', 'good', 'match'],
#  ['going', 'bed', 'school', 'people', 'really', 'crazy', 'mean', 'wow', 'bye'],
#  ['user_7b0344f9',
#   'didnt',
#   'need',
#   'talk',
#   'anything',
#   'cause',
#   'nothing',
#   'talk',
#   'stuck',
#   'girl',
#   'one'],
#  ['user_7b0344f9',
#   'shocking',
#   'like',
#   'done',
#   'turn',
#   'around',
#   'start',
#   'shit',
#   'knew',
#   'ya',
#   'meant'],
#  ['user_7b0344f9', 'ha', 'bristol', 'kyles', 'house'],
#  ['im', 'really', 'tired', 'ttyl', 'everyone'],
#  ['yes',
#   'user_25f2ef26',
#   'startin',
#   '2nd',
#   'user_9a450357',
#   'starting',
#   '5th',
#   'taylor',
#   'malsam',
#   'starting',
#   '11th'],
#  ['user_89d77ef0', 'yea'],
#  ['oh', 'god', 'sister', 'driving'],
#  ['woot',
#   'rt',
#   'user_d223b772',
#   'voted',
#   'team',
#   'kylejoey',
#   'gillette500com',
#   'nascar'],
#  ['truck', 'set', 'time'],
#  ['woot'],
#  ['go', 'user_25f2ef26', 'also', 'user_db41731c', 'user_9a450357'],
#  ['woo', 'great', 'save', 'todd', 'holy', 'shit', 'dirt', 'racin', 'shit'],
#  ['user_f214f7df', 'aww'],
#  ['need', 'caution'],
#  ['alright', 'got', 'ta', 'go', 'phone', 'die', 'bye', 'everyone'],
#  ['lol',
#   'thats',
#   'thinkin',
#   'rt',
#   'user_7b0344f9',
#   'aka',
#   'juan',
#   'jealous',
#   'jamie',
#   'lol'],
#  ['good', 'pick', 'kyle', 'kyle', 'busch'],
#  ['gon', 'na', 'eat', 'oodles', 'noodle', 'start', 'homework'],
#  ['user_1edded30', 'kyle', 'busch', 'gon', 'na', 'win', 'today'],
#  ['yea'],
#  ['damn',
#   'u',
#   'robby',
#   'well',
#   'cant',
#   'say',
#   'im',
#   'surprised',
#   'he',
#   'first',
#   'caution'],
#  ['user_b55dadbe', 'p7'],
#  ['user_d223b772', 'haha', 'would', 'cause', 'riot'],
#  ['shit', 'kyles', 'got', 'ta', 'vibration'],
#  ['2', 'dennys', 'as'],
#  ['shut', 'larry', 'fuckin', 'reminder', 'last', 'year'],
#  ['user_370c8719',
#   'one',
#   'seemeed',
#   'long',
#   'maybe',
#   'cause',
#   'boy',
#   'havin',
#   'problem'],
#  ['oh', 'jeff'],
#  ['user_7b0344f9',
#   'tire',
#   'fucked',
#   'im',
#   'ready',
#   'tire',
#   'rant',
#   'done',
#   'race',
#   'chase',
#   'time'],
#  ['user_2b90e2b7', 'yea', 'making', 'mad', 'hope', 'get', 'worked'],
#  ['thunder', 'valley', 'next', 'week', 'kyles', 'house'],
#  ['steve'],
#  ['another', 'disappointing', 'race', 'get', 'ur', 'shit', 'together'],
#  ['dont',
#   'want',
#   'juan',
#   'win',
#   'come',
#   'kurtcant',
#   'believe',
#   'im',
#   'roting'],
#  ['think',
#   'payback',
#   'finally',
#   'got',
#   'he',
#   'dishing',
#   'saying',
#   'im',
#   'glad',
#   'flipped',
#   'brad',
#   'dick'],
#  ['come', 'matt'],
#  ['fuck',
#   'would',
#   'suspend',
#   'carl',
#   'im',
#   'gon',
#   'na',
#   'fuckin',
#   'riot',
#   'anybody',
#   'else',
#   'teamedwards',
#   'forever'],
#  ['user_708955d8', 'im', 'actually', 'excited', 'see', 'u', 'say'],
#  ['user_2b2bd61b',
#   'light',
#   'skin',
#   'free',
#   'way',
#   'shitlol',
#   'look',
#   'like',
#   'sell',
#   'bean',
#   'pie'],
#  ['user_7ac8dee6', 'hey', 'cuzwhere', 'u'],
#  ['good', 'morning', 'world'],
#  ['slowjamz', 'rap', 'today'],
#  ['aye',
#   'baby',
#   'crazy',
#   'tweet',
#   'say',
#   'maybe',
#   'well',
#   'crazy',
#   'know',
#   'im',
#   'fly'],
#  ['user_a88583ac', 'fma'],
#  ['user_fec9be80', '70', 'hell', 'u', 'goinits', 'wed'],
#  ['user_cb10b466', 'nooolol'],
#  ['user_f57bb122', 'raining'],
#  ['bout', 'finally', 'get', 'bed'],
#  ['pussy', 'pussy', 'get', 'need'],
#  ['user_19ee25ab', 'real', 'random'],
#  ['user_a57625a4', 'would', 'suck', 'smh'],
#  ['user_4e5bb214', 'true'],
#  ['cant', 'give', 'woman', 'attention', 'want', 'get', 'pay', 'attention'],
#  ['user_313606bf', 'tru'],
#  ['user_a48db5e1', 'lmfao'],
#  ['user_f33607a3', 'yea', 'dat', 'shitlol'],
#  ['user_5e49495b', 'make', 'way', 'treatinglol'],
#  ['brutha', 'group', 'chillz', 'ituning', 'mac', 'shit'],
#  [],
#  ['realthugs', 'tell', 'girl', 'phat', 'shit', 'holding', 'hand'],
#  ['user_f25ba984', 'go', 'peer', 'pressure'],
#  ['ever',
#   'heard',
#   'food',
#   'way',
#   'man',
#   'heart',
#   'dont',
#   'think',
#   'got',
#   'memolol',
#   'subtweet',
#   'okay',
#   'im',
#   'donelol'],
#  ['almost', 'time'],
#  ['user_136b9b4a',
#   'lmfaolook',
#   'like',
#   'somebody',
#   'bout',
#   '2',
#   'eating',
#   'as',
#   'picsmh'],
#  ['user_b71ed7f4', 'naw', 'dontlmao'],
#  ['stay', 'home', 'alot', 'tv', 'thought'],
#  ['user_1bf6f77a', 'wats', 'confusing'],
#  ['im', 'coolbut', 'hate'],
#  ['user_a88583ac', 'iam', 'blaming', 'twitterlol'],
#  ['user_dfea9c35', 'yea', 'play', 'acoustic'],
#  ['hoe', 'nothing', 'hoe', 'cant', 'keep', 'leg', 'closed'],
#  ['slow', 'motion', 'better', 'motion', 'never', 'stop', 'progressing'],
#  ['white', 'bitch', 'next', '2', 'stink', 'like', 'shitsmh'],
#  ['sitting',
#   'like',
#   'shoulder',
#   'length',
#   'keep',
#   'looking',
#   'screen',
#   'know',
#   'see',
#   'tweetsmh'],
#  ['need',
#   'get',
#   'go',
#   'class',
#   'chick',
#   'ask',
#   'another',
#   'question',
#   'ima',
#   'pack',
#   'as'],
#  ['cant', 'call', 'somethingaintright'],
#  ['user_979c9a44', 'college', 'party'],
#  ['user_136b9b4a',
#   'damnlol',
#   'yea',
#   'got',
#   'car',
#   'tho',
#   'dont',
#   'got',
#   'john',
#   'hit',
#   'lloyd',
#   'melol'],
#  ['user_a88583ac', 'melol'],
#  ['ima', 'cool', 'cat', 'life', '9'],
#  ['stomach', 'touching', 'back', 'smh', 'got', 'ta', 'eat'],
#  ['whats', 'ppl'],
#  ['woman', 'cant', 'get', 'touch', 'still', 'feeling'],
#  ['mind', 'mad', 'heart'],
#  ['user_5c3ffa2f', 'fucs', 'wit', 'lupe'],
#  ['eye', 'heavy'],
#  ['user_5c3ffa2f', 'powlol'],
#  ['user_f33607a3', 'u', 'shakin', 'ya', 'head', 'm'],
#  ['smelling', 'like', 'burberry', 'colone'],
#  ['user_1535af14', 'girl', 'u', 'know', 'u', 'bad', 'gurllol'],
#  ['drunker',
#   'motherfuckerlol',
#   'ima',
#   'bout',
#   '2',
#   'end',
#   'nite',
#   'alone',
#   'usually',
#   'lol'],
#  ['wtf', 'talkin', 'bout', 'last', 'nite'],
#  ['user_1535af14', 'yes', 'waslol'],
#  ['user_9d8eecaa', 'lol', 'hahahhahahaaaaa'],
#  ['user_9d8eecaa', 'cheesing', 'yeah', 'right', 'lol'],
#  ['user_20780314', 'hahahhaaa', 'wan', 'na', 'play', 'humph'],
#  ['user_34f7b18a', 'thats', 'kool'],
#  ['user_9d8eecaa', 'ok', 'bringem'],
#  ['user_34f7b18a', 'im', 'tremendously', 'well', 'thank'],
#  ['user_9d8eecaa', 'lmao', 'yeah', 'yeah', 'yeah', 'shut'],
#  ['user_9d8eecaa', 'telling', 'asking'],
#  ['user_9d8eecaa', 'said', 'way', 'dnt', 'dnt', 'want', 'saying'],
#  ['user_9d8eecaa', '1st', 'time', 'seen'],
#  ['user_c5f00de2', 'user_cd29704a', 'waka', 'flocka', 'flame', 'lmao'],
#  ['user_c5f00de2', 'ipromise'],
#  ['user_c5f00de2',
#   'ughhhhhh',
#   'cheesecake',
#   'well',
#   'dnt',
#   'promise',
#   'hurry'],
#  ['user_e56afc79', 'like', 'bkgrd', 'pic', 'left', 'nice'],
#  ['user_c5f00de2'],
#  ['user_9fc012e1', 'damn', 'finally', 'line', 'homie'],
#  ['user_20780314',
#   'brooklyn',
#   'finest',
#   'alice',
#   'wonderland',
#   'come',
#   'friday',
#   'yay',
#   'going',
#   'together'],
#  ['user_20780314', 'lmao', 'fl'],
#  ['rt',
#   'user_e6d3453d',
#   'oh',
#   'shit',
#   'duck',
#   'lol',
#   'yall',
#   'stop',
#   'dis',
#   'shit',
#   'lol',
#   'rt',
#   'user_cd29704a',
#   'user_f6fd3b3e',
#   'haha',
#   'high',
#   'fivevirtual',
#   'high5',
#   'coming',
#   'ur',
#   'way',
#   'sooo'],
#  ['user_48b79a87', 'welcome'],
#  ['im',
#   'love',
#   'marc',
#   'bell',
#   'artistic',
#   'work',
#   'art',
#   'outstandingly',
#   'breath',
#   'taking',
#   'stare',
#   'work',
#   'day'],
#  ['rock',
#   'j',
#   'walker',
#   'talented',
#   'get',
#   'every',
#   'little',
#   'detail',
#   'well',
#   'marc',
#   'bell',
#   'research',
#   'go',
#   'home'],
#  ['user_e539ecd4',
#   'user_a3f9484b',
#   'ight',
#   'favorite',
#   'host',
#   'far',
#   'everything',
#   'going',
#   'according',
#   'plan',
#   'im',
#   'going',
#   'set',
#   'meeting',
#   'everyone'],
#  ['user_e539ecd4',
#   'user_a3f9484b',
#   'send',
#   'availability',
#   'dm',
#   'please',
#   'thank'],
#  ['user_b3bdd029', 'lmao'],
#  ['user_067e0c87', 'yea', 'know', 'going'],
#  ['shoutout',
#   '2all',
#   'beckz',
#   'icamacross',
#   'user_8166e580',
#   'user_75ca71d4',
#   'user_2ac84d7c',
#   'user_ac9da2f2',
#   'user_2d2346d4',
#   'user_0372f59f',
#   'user_ccecedc9',
#   'user_44920d9f'],
#  ['user_b88f61f0', 'hahahhahaaaa', 'lol'],
#  ['followfriday', 'user_32a394af'],
#  ['followfriday', 'user_ebbd98f0'],
#  ['user_32a394af', 'lol', 'nothing', 'much', 'hanging', 'n'],
#  ['followfriday', 'user_b300ea8f'],
#  ['gone', 'missing'],
#  ['oh', 'let'],
#  ['finally', 'reached', 'home', 'tolong', 'ago', 'goodnight'],
#  ['rt',
#   'user_8fe38169',
#   'user_e968a207',
#   'user_8fe38169',
#   'user_e968a207',
#   'user_8fe38169',
#   'user_e968a207',
#   'user_8fe38169',
#   'user_e968a207',
#   'user_8fe38169',
#   'retweet'],
#  ['user_a3f9484b', 'yo', 'yo', 'yo', 'mic', 'check', '12', '1', '2', 'lol'],
#  ['love', 'life'],
#  ['hear', '3', 'user_8b0d919a', 'truthis', 'user_0874d64d', 'gay'],
#  ['user_a3f9484b', 'idk', 'yet', 'thing', 'mind'],
#  ['user_8fe38169',
#   'lol',
#   'thinking',
#   'looking',
#   'calendar',
#   'book',
#   'almost',
#   'ready',
#   'lol'],
#  ['user_a3f9484b'],
#  ['user_8f283901', 'thats', 'wussup', 'go'],
#  ['club',
#   'cinema',
#   'swole',
#   'tonight',
#   'like',
#   'wow',
#   'cant',
#   'wait',
#   'go',
#   'inside'],
#  ['ok', 'crazy', 'baning', 'im', 'ready', 'go', 'home'],
#  ['rt',
#   'user_e513cbc9',
#   'told',
#   'follow',
#   'back',
#   'yo',
#   'page',
#   'private',
#   'accessdenied'],
#  ['twitterbreak', 'ive', 'alot', 'today'],
#  ['shoutout', 'thebirthdaygirl', 'gt', 'user_042fb344'],
#  ['awwwwww',
#   'need',
#   'girl',
#   'came',
#   'miss',
#   'boston',
#   'aunt',
#   'would',
#   'change',
#   'lyric',
#   'need',
#   'husband',
#   'who',
#   'realest',
#   'lol'],
#  ['cant',
#   'believe',
#   'ill',
#   '21',
#   'next',
#   'month',
#   'verging',
#   'grownmanstatus',
#   'serious'],
#  ['rt', 'user_a7a7dfed', 'rt', 'user_72ee3b2e', 'praise', 'due', '2', 'allah'],
#  ['111', 'make', 'wish'],
#  ['user_6673c70b', 'lol', 'exactly', 'lmao'],
#  ['today',
#   'pretty',
#   'good',
#   'day',
#   'omw',
#   'movie',
#   'premiere',
#   'brooklyn',
#   'finest'],
#  ['need',
#   'refrain',
#   'putting',
#   'stuff',
#   'relationship',
#   'herei',
#   'close',
#   'tweeting',
#   'something',
#   'happened'],
#  ['movie',
#   'im',
#   'sitting',
#   '70yr',
#   'old',
#   'lady',
#   'foot',
#   'man',
#   'couple',
#   'who',
#   'love',
#   'playfighting',
#   'killmealready'],
#  ['theyre',
#   'blasting',
#   'user_a8349405',
#   'movie',
#   'theater',
#   'movie',
#   'premiere',
#   'start',
#   'im',
#   'smiling',
#   'singing',
#   'along',
#   'lol'],
#  ['1111', 'make', 'wish', 'central', 'time'],
#  ['saying',
#   'hello',
#   'couple',
#   'ppl',
#   'fb',
#   'havent',
#   'talked',
#   'shotout',
#   'dominique',
#   'ebony',
#   'miko',
#   'maysoun',
#   'mikeglaspie',
#   'philip'],
#  ['swear',
#   'add',
#   'lol',
#   'one',
#   'minute',
#   'im',
#   'depressed',
#   'next',
#   'digress',
#   'lol',
#   'tried',
#   'rhyme',
#   'hahaha'],
#  ['looking', 'new', 'follower', 'old', 'one', 'slackingall', 'lol'],
#  ['earlyout', 'habit', 'ppl', 'waking', 'sleep', 'smh'],
#  ['march', '14', 'love', 'day', 'valentine', 'day', 'single', 'rt'],
#  ['rt',
#   'user_f0735b55',
#   'rock',
#   'eyebrow',
#   'upload',
#   'pik',
#   'ltits',
#   'early',
#   'uploading',
#   'pic'],
#  ['jibber', 'jabeer', 'soooooooooo', 'cool', 'lol', 'always', 'make', 'day'],
#  ['receive', 'ff', 'im', 'mood', 'participate'],
#  ['rt', 'user_31f168ac', 'user_de733004', 'im', 'good', 'lthungry'],
#  ['gon', 'na', 'poppin', 'get', 'new', 'york', 'yo'],
#  ['ohhhhhhhh', 'sudden', 'want', 'breakfast', 'klub', 'fish', 'grit'],
#  ['lol',
#   'thats',
#   'keep',
#   'asking',
#   'myselfwhen',
#   'go',
#   'lol',
#   'rt',
#   'user_ddb7ae9c',
#   'lil',
#   'wayne',
#   'tweetin',
#   'prison'],
#  ['gym', '40', 'minute', 'workout', 'let', 'go'],
#  ['rt',
#   'user_d3c9d057',
#   'rt',
#   'user_c8a904d8',
#   'everyone',
#   'claim',
#   'realmost',
#   'people',
#   'arent',
#   'real',
#   'u',
#   'say',
#   'u',
#   'treat',
#   'ppl'],
#  ['rt',
#   'user_6df5d459',
#   'rt',
#   'user_d28cbf8f',
#   'ff',
#   'user_d28cbf8f',
#   'user_828c1ce3',
#   'user_f3af890d',
#   'user_6df5d459',
#   'user_de733004',
#   'user_f081bfa9'],
#  ['going',
#   'alcohol',
#   'aisle',
#   'grocery',
#   'store',
#   'smiling',
#   'next',
#   'month',
#   'ill',
#   'able',
#   'buy',
#   'anything',
#   'aisle',
#   'lol'],
#  ['havent',
#   'eatin',
#   '13',
#   'rt',
#   'user_6673c70b',
#   '10',
#   'hour',
#   'since',
#   'last',
#   'time',
#   'ive',
#   'eaten',
#   'good',
#   'need',
#   'something',
#   'dish',
#   'later'],
#  ['lol',
#   'silly',
#   'rt',
#   'user_1908cc61',
#   'user_de733004',
#   'sure',
#   'u',
#   'walk',
#   'ill',
#   'take',
#   'train'],
#  ['ok',
#   'im',
#   'finally',
#   'full',
#   'turkey',
#   'sandwhich',
#   'bbq',
#   'chip',
#   'chicken',
#   'alfredo',
#   'seasoned',
#   'broccoli',
#   'garlic',
#   'breadstick',
#   'whew',
#   'naptime'],
#  ['user_0ca2cc69',
#   'wicked',
#   'favorite',
#   'musical',
#   'ive',
#   'scene',
#   'touring',
#   'version',
#   'wan',
#   'na',
#   'see',
#   'there',
#   'many',
#   'show',
#   'need'],
#  ['user_57bea3fb',
#   'previewed',
#   'itunes',
#   'im',
#   'omw',
#   'bestbuy',
#   'cuz',
#   'liked',
#   'much',
#   'think',
#   'intheheights',
#   'winning',
#   'far'],
#  ['2', 'height', '1', 'fela', '1', 'west', 'side', 'storyany', 'vote'],
#  ['lol',
#   'quick',
#   'ff',
#   'user_28a8f15e',
#   'he',
#   'tweeting',
#   'ver',
#   'good',
#   'story',
#   'lol'],
#  ['user_28a8f15e',
#   'hahahaha',
#   'oh',
#   'god',
#   'lol',
#   'yur',
#   'fukn',
#   'stupid',
#   'lol',
#   'good',
#   'fun',
#   'school',
#   'went',
#   'lol'],
#  ['user_d0899bc8',
#   'im',
#   'gooood',
#   'room',
#   'texting',
#   'kinda',
#   'hot',
#   'tho',
#   'smh'],
#  ['user_d0899bc8', 'going', 'fast', 'enough'],
#  ['user_250d25dd',
#   'didddddd',
#   'dont',
#   'remember',
#   'little',
#   'liar',
#   'lol',
#   'woke',
#   'smh',
#   'supertired'],
#  ['getthefuckouttahere',
#   'im',
#   'bout',
#   'eat',
#   'breakfast',
#   'rt',
#   'user_a08edf1b',
#   'user_a4abac17',
#   'aww',
#   'cmon',
#   'lil',
#   'cat',
#   'nvr',
#   'hurt',
#   'body',
#   'lmfao'],
#  ['rt',
#   'user_417c1789',
#   'rt',
#   'user_de733004',
#   'ff',
#   'ledgen',
#   'user_417c1789',
#   'name',
#   'reflection',
#   'ltcorrection'],
#  ['user_250d25dd', 'fucking', 'stalkerin', 'every', 'sense', 'word', 'lol'],
#  ['stuckinmyhead',
#   'cousin',
#   'dance',
#   'like',
#   'drunk',
#   'chita',
#   'rivera',
#   'lol',
#   'intheheights'],
#  ['lol', 'rt', 'user_31f168ac', 'rarely', 'check', 'dm'],
#  ['user_6673c70b', 'lol'],
#  ['baby', 'still', 'sleepsleeping', 'beauty', 'lol'],
#  ['user_a7a7dfed', 'hate', 'ppl', 'walking', 'together', 'split', 'pole', '_'],
#  ['user_417c1789',
#   'yeahhh',
#   'thats',
#   'think',
#   'u',
#   'come',
#   'ny',
#   'lol',
#   'u',
#   'came',
#   'would',
#   'pay'],
#  ['user_417c1789', 'yes'],
#  ['going', 'bed', 'anytime', 'soon'],
#  ['user_5c679954', 'imma', 'prove', 'hand', 'face'],
#  ['user_e0f7e418', 'better', 'gamble'],
#  ['user_38b11087', 'hell', 'yea', 'would', 'laugh'],
#  ['user_bdaccc7d', 'forget', 'nice'],
#  ['shaquanna', 'godbolt', 'bdl', 'cut', 'user_5c679954'],
#  ['user_38b11087', 'cant', 'help'],
#  ['rt',
#   'user_e0f7e418',
#   'unotfromthehood',
#   'u',
#   'havent',
#   'sheet',
#   'ur',
#   'window',
#   'curtain'],
#  ['user_25b79648',
#   'oh',
#   'true',
#   'haha',
#   'goodthat',
#   'didnt',
#   'happen',
#   'though',
#   'clowning'],
#  ['user_25b79648', 'ah', 'shoot'],
#  ['user_86b8c6ce', 'alright', 'bet'],
#  ['peanut', 'away', 'died'],
#  ['user_368e3dce', 'ah', 'fooey'],
#  ['rt',
#   'user_b283f72c',
#   '78',
#   'obese',
#   'people',
#   'intimidated',
#   'big',
#   'headed',
#   'broadsgtso',
#   'saying',
#   'brynne',
#   'intimidated',
#   'shay'],
#  ['freshman',
#   'fgcu',
#   'chancesare',
#   'hoe',
#   'done',
#   'let',
#   'atleast',
#   'two',
#   'people',
#   'school',
#   'smash',
#   'first',
#   'semester',
#   'alone'],
#  ['uh', 'oh'],
#  ['rt',
#   'user_9a7ec579',
#   'girl',
#   'playing',
#   'ball',
#   'chancesare',
#   'people',
#   'think',
#   'youre',
#   'gay',
#   'easiest',
#   'way',
#   'get',
#   'close',
#   'man',
#   'tho',
#   'lls'],
#  ['vote', 'steak', 'shake'],
#  ['user_77899b70', 'one', 'waffle', 'house'],
#  ['user_e99a08cc', 'left', 'applebees'],
#  ['user_52040410', 'im', 'way'],
#  ['famu', 'sex', 'tape', 'eating', 'booty', 'hole', 'eatthebootyholeout'],
#  ['lol', 'yo', 'arguing', 'eating', 'booty', 'hole', 'haha', 'life'],
#  ['follower', 'eat', 'booty', 'hole', 'press', '1'],
#  ['user_b283f72c', 'eww', 'well', 'dang', 'gucci', 'voice'],
#  ['user_b283f72c', 'preach'],
#  ['user_fa95a989', 'lol', 'turn', 'back', 'imma', 'steal', 'supply'],
#  ['betmessedupwhen',
#   'got',
#   'rid',
#   'citas',
#   'world',
#   'remember',
#   'animated',
#   'black',
#   'lady',
#   'lol'],
#  ['betmessedupwhen', 'got', 'rid', 'comicview'],
#  ['user_dd09a02b', 'lol', 'get', 'famu'],
#  ['youyoure', 'going', 'love', 'meeeeeee'],
#  ['user_368e3dce', 'lol', 'touche', 'nig', 'touche', 'haha'],
#  ['user_8c20e50d', 'thats', 'song', 'yo'],
#  ['nowplaying', 'wale', 'ft', 'gucci', 'mane', 'pretty', 'girl'],
#  ['ugly', 'girl', 'quiet', 'quietpretty', 'girl', 'clap', 'clap', 'like'],
#  ['user_7845a735', 'whats', 'upper'],
#  ['user_5c679954',
#   'cut',
#   'doesnt',
#   'countyou',
#   'cant',
#   'put',
#   'feeling',
#   'done',
#   'told',
#   'dont',
#   'tweeting',
#   'name',
#   'wrong'],
#  ['user_5c679954', 'whatever', 'shaquanna', 'didnt', 'end', 'discussion'],
#  ['user_5c679954',
#   'itsnotcool',
#   'give',
#   'false',
#   'credit',
#   'cant',
#   'put',
#   'feeling',
#   'cut',
#   'letsbereal'],
#  ['user_5c679954', 'yes', 'mam', 'wont'],
#  ['user_7845a735',
#   'fool',
#   'indeed',
#   'called',
#   'asking',
#   'still',
#   'eff',
#   'himthe',
#   'hell',
#   'random'],
#  ['user_7845a735', 'got', 'mad', 'laughinghe', 'feeling'],
#  ['lol',
#   'oh',
#   'em',
#   'gee',
#   'yo',
#   'krystal',
#   'mcfadden',
#   'showing',
#   'today',
#   'giving',
#   'twitter',
#   'entirely',
#   'much'],
#  ['user_5c679954', 'o_o'],
#  ['nowplaying', 'miley', 'cyrus', 'climb'],
#  ['nowplaying', 'silk'],
#  ['user_bf9cfc0e', 'deactivate', 'facebook', 'tweetaholic'],
#  ['o_o'],
#  ['user_bf9cfc0e', 'mkay'],
#  ['user_bf9cfc0e', 'wise', 'tweet'],
#  ['user_b283f72c', 'cut'],
#  ['user_d05bca1a', 'rell', 'life', 'life', 'flea', 'bdl', 'though'],
#  ['rt',
#   'user_b283f72c',
#   'mewithoutyouislike',
#   'pompano',
#   'beach',
#   'without',
#   'bran',
#   'bgtlol',
#   'stupid'],
#  ['user_08e37258', 'haha', 'lol'],
#  ['user_b283f72c', 'haha', 'boy', 'aint', 'got', 'nothing', '20'],
#  ['user_d59f7ec4', 'man', 'stay', 'getting', 'messed'],
#  ['user_5c679954', 'im', 'ready', 'slap', 'hoecause', 'clearly'],
#  ['user_068502b7',
#   'calling',
#   'liar',
#   'let',
#   'remind',
#   'sherell',
#   'yall',
#   'talking',
#   'uh',
#   'huh',
#   'yea',
#   'win'],
#  ['user_38b11087', 'chilling', 'whats', 'upper'],
#  ['user_b283f72c', 'hopefully', 'today'],
#  ['user_5c679954', 'yes'],
#  ['user_5c679954', 'like', 'big', 'chat', 'room', 'u'],
#  ['user_5c679954',
#   'still',
#   'itnever',
#   'going',
#   'get',
#   'done',
#   'called',
#   'tradersmh'],
#  ['tattoo',
#   'artist',
#   'cute',
#   'asian',
#   'dread',
#   'need',
#   'flirt',
#   'get',
#   'discounted',
#   'tat',
#   'future',
#   'user_bf9cfc0e'],
#  ['user_bf9cfc0e', 'tat'],
#  ['lol', 'man', 'tweeting', 'funeral'],
#  ['user_77899b70',
#   'thats',
#   'funny',
#   'im',
#   'listening',
#   'nowa',
#   'reason',
#   'hate'],
#  ['user_5685c393',
#   'would',
#   'let',
#   'lick',
#   'stick',
#   'ityou',
#   'wasnt',
#   'supposed',
#   'answer',
#   'lol'],
#  ['user_5685c393',
#   'alright',
#   'cool',
#   'club',
#   'though',
#   'dont',
#   'really',
#   'feel',
#   'like',
#   'clubbing'],
#  ['user_5f4d8536', 'dade', 'tonight'],
#  ['user_5f4d8536', 'thats', 'need', 'know'],
#  ['user_5f4d8536', 'walking', 'strip'],
#  ['google'],
#  ['user_bf9cfc0e', 'well', 'south', 'beach', 'rip', 'beverage'],
#  ['user_9a7ec579', 'lol', 'tights', 'nothing', 'wearing', 'lacefront', 'haha'],
#  ['user_2d6d8d46',
#   'lol',
#   'grill',
#   'didnt',
#   'stop',
#   'alli',
#   'went',
#   'back',
#   'take',
#   'haha'],
#  ['better', 'adjust', 'attitude', 'turn', 'altitiude'],
#  ['user_e0f7e418', 'cut'],
#  ['user_b283f72c',
#   'come',
#   'delta',
#   'shout',
#   'stronger',
#   'zeta',
#   'shout',
#   'smh'],
#  ['user_06c597f9', 'um', 'humi', 'bet', 'fish', 'dead'],
#  ['rt',
#   'user_f83b8de7',
#   'excl',
#   'stylesocial',
#   'beyonce',
#   'shoe',
#   'chai',
#   'tea',
#   'served',
#   'w',
#   'gianmarco',
#   'lorenzicatch',
#   'alicia',
#   'key',
#   'video'],
#  ['super',
#   'modal',
#   'world',
#   'make',
#   'headline',
#   'altercation',
#   'workmuch',
#   'luv',
#   'prayer',
#   'sister',
#   'naomi'],
#  ['rt', 'user_787c9dc0', 'im', 'bitchltyess', 'u'],
#  ['heading', 'home', 'im', 'stuff', 'good', 'food', 'eat', 'today'],
#  ['okay', 'yalll', 'user_12b7d993', 'jayz', 'concert', 'retweeting', 'tweet'],
#  ['rt',
#   'user_12b7d993',
#   'lebran',
#   'james',
#   'step',
#   'motherfucking',
#   'building',
#   'seating',
#   'two',
#   'row',
#   'infront'],
#  ['oh',
#   'wow',
#   'didnt',
#   'monica',
#   'lates',
#   'music',
#   'video',
#   'everything',
#   'dedicated',
#   'alexander',
#   'mcqueen',
#   'awesome'],
#  ['rtclighty',
#   'getting',
#   'ahead',
#   'difficult',
#   'profession',
#   'requires',
#   'avid',
#   'faith'],
#  ['yes', 'lip', 'sing', 'ur', 'life', 'rupaul', 'drag', 'race', 'kee', 'kee'],
#  ['rt', 'user_ba79eb4e', 'life', 'like', 'mirror', 'smile', 'smile', 'back'],
#  ['user_5a44b70d', 'thanx', 'boo'],
#  ['timeline',
#   'cablevision',
#   'someone',
#   'plz',
#   'look',
#   'bill',
#   'give',
#   'customer',
#   'service'],
#  ['rt',
#   'user_161c56a9',
#   'timeline',
#   'cablevision',
#   'someone',
#   'plz',
#   'look',
#   'bill',
#   'give',
#   'customer',
#   'service'],
#  ['someone', 'plz', 'help'],
#  ['project', 'runway', 'minutesyaaayyy'],
#  ['rt',
#   'user_d94b3dce',
#   'finishing',
#   'theraflu',
#   'gon',
#   'na',
#   'doze',
#   'devil',
#   'wear',
#   'pradaltaww',
#   'pumpkin',
#   'get',
#   'well',
#   'soon'],
#  ['oh',
#   'barber',
#   'shop',
#   'boy',
#   'freak',
#   'outtalking',
#   'armpit',
#   'feetdoesnt',
#   'make',
#   'happy'],
#  ['put', 'follower', 'im', 'street'],
#  ['rtwwdrecalling',
#   'notorioushumps',
#   'collectionforspring97rei',
#   'kawakubo',
#   'stuffed',
#   'comme',
#   'de',
#   'garãons',
#   'collection',
#   'pillowlike',
#   'padding'],
#  ['rt',
#   'user_a642a2e3',
#   'beautiful',
#   'day',
#   'ny',
#   'today',
#   'hope',
#   'beautiful',
#   'ur',
#   'neck',
#   'wood'],
#  ['rt',
#   'user_ba79eb4e',
#   'prada',
#   'sample',
#   'sale',
#   'woodbury',
#   'common',
#   'premium',
#   'outlet',
#   'ny',
#   'sun',
#   'mar',
#   '7',
#   'store',
#   'opening',
#   '9am'],
#  ['rt',
#   'user_ba79eb4e',
#   'quote',
#   'weekend',
#   'much',
#   'much',
#   'enjoy',
#   'make',
#   'happiness'],
#  ['user_5a44b70d', 'wat', 'u', 'booboo'],
#  ['offical', 'crush', 'justin', 'bieber', 'hehehehe'],
#  ['whyyyy'],
#  ['wit', 'boo', 'user_40b1d442', 'eating', 'food'],
#  ['way', 'workkk', 'ughhh'],
#  ['user_40b1d442',
#   'u',
#   'love',
#   'bishhh',
#   'ur',
#   'as',
#   'one',
#   'takin',
#   'shot',
#   'last',
#   'night',
#   'sayin',
#   'u',
#   'smh'],
#  ['letsbereal',
#   'guy',
#   'fun',
#   'wit',
#   'sidechick',
#   'wife',
#   'thats',
#   'sooo',
#   'fucked',
#   'thosmh'],
#  ['wan', 'na', 'go', 'home', 'cuddle', 'chico'],
#  ['user_3170607a',
#   'hahaha',
#   'imma',
#   'look',
#   'fly',
#   'long',
#   'weave',
#   'dontjudgeme'],
#  ['rt',
#   'user_40b1d442',
#   'user_f5c7cb2d',
#   'ill',
#   'help',
#   'u',
#   'u',
#   'babysit',
#   'son',
#   'omg',
#   'louie',
#   'ill',
#   'keep'],
#  ['rt',
#   'user_40b1d442',
#   'user_f5c7cb2d',
#   'yes',
#   'take',
#   'himmmmm',
#   'u',
#   'tomorroe',
#   'yes',
#   'biaaa',
#   'u',
#   'got',
#   'date',
#   'wit',
#   'homo'],
#  ['win', 'win', 'win', 'matter'],
#  ['ill',
#   'pay',
#   'someone',
#   'laundry',
#   'way',
#   'much',
#   'little',
#   'ol',
#   'handle',
#   'ughhh'],
#  ['user_40b1d442', 'u', 'din', 'din', 'ready'],
#  ['im', 'known', 'chill', 'wit', 'thug', '2'],
#  ['love', 'drizzy', 'drake'],
#  ['user_3b7be318', 'still', 'come', 'im', 'go', 'get'],
#  ['user_3b7be318', 'ok', 'guess', 'nex', 'time', 'thanks', 'anyway'],
#  ['user_4302922c',
#   'know',
#   'right',
#   'cant',
#   'find',
#   'anyone',
#   'helloooooooo',
#   'anybody'],
#  ['workiess', 'runnin', '2', 'hour', 'sleep', 'ughhh'],
#  ['remember', 'never', 'go', 'saturdaysughhh'],
#  ['user_2d686697', 'know', 'suxs'],
#  ['rt', 'user_40b1d442', 'dinner', 'user_3170607a', 'im', 'jelly'],
#  ['user_3170607a',
#   'user_40b1d442',
#   'get',
#   'work',
#   'soon',
#   'im',
#   'pjs',
#   'lol',
#   'u',
#   'guy'],
#  ['sleep', 'since', 'like', '1pm', 'im', 'still', 'hella', 'tired', 'world'],
#  ['user_3d8ec5da',
#   'guy',
#   'say',
#   'there',
#   'way',
#   'american',
#   'get',
#   'money',
#   'collecting',
#   'unemployement',
#   'blk',
#   'guy',
#   'asks'],
#  ['soon',
#   'black',
#   'guy',
#   'say',
#   'else',
#   'user_3d8ec5da',
#   'cut',
#   'wtf',
#   'wanted',
#   'hear',
#   'guy',
#   'dumbass',
#   'answer'],
#  ['march',
#   '4th',
#   'user_4b217ebf',
#   'blue',
#   'que',
#   '28th',
#   'jst',
#   'bsmoove',
#   'video',
#   'release',
#   'perf',
#   'user_6113e677',
#   'user_0f2298e5',
#   'user_6fa634bd',
#   'bsmoove',
#   'mo'],
#  ['user_4f9aaa7c',
#   'producer',
#   'tho',
#   'feel',
#   'person',
#   'want',
#   'buy',
#   'beat',
#   'u',
#   'pretty',
#   'wah',
#   'wah',
#   'dont',
#   'give',
#   'exsclusives',
#   'lol'],
#  ['user_4f9aaa7c',
#   'sure',
#   'im',
#   'tired',
#   'walking',
#   'subway',
#   'guy',
#   'making',
#   'foot',
#   'long',
#   'telling',
#   'business',
#   'plan',
#   'rap'],
#  ['uhm',
#   'yeah',
#   'anyone',
#   'else',
#   'fetish',
#   'watch',
#   '2',
#   'midget',
#   'hump',
#   'mean',
#   'jus',
#   'wan',
#   'na',
#   'see',
#   '2gether'],
#  ['think',
#   'going',
#   'name',
#   'debut',
#   'solo',
#   'album',
#   'fresh',
#   'porch',
#   'yall',
#   'think',
#   'u',
#   'got',
#   'better',
#   'name',
#   'let',
#   'hear'],
#  ['rt',
#   'user_1619ad76',
#   'march',
#   '26th',
#   'silk',
#   'bar',
#   'user_1ca77d94',
#   'user_538a815d',
#   'user_02373afd',
#   'user_1328facb',
#   'mark',
#   'ya',
#   'calendar',
#   'bcuz',
#   'u',
#   'dnt',
#   'want',
#   'miss'],
#  ['yo',
#   'thats',
#   'hella',
#   'good',
#   '1',
#   'right',
#   'rt',
#   'user_1619ad76',
#   'user_6113e677',
#   'like',
#   'porch',
#   'politician'],
#  ['follow',
#   'user_6113e677',
#   'user_6113e677',
#   'user_6113e677',
#   'user_6113e677',
#   'user_6113e677',
#   'user_6113e677',
#   'user_6113e677',
#   'user_6113e677',
#   'user_6113e677',
#   'user_6113e677',
#   'user_6113e677',
#   'user_6113e677',
#   'user_6113e677',
#   'user_6113e677',
#   'user_6113e677',
#   'user_6113e677'],
#  ['queen',
#   '2',
#   'follow',
#   'user_9e7db6ee',
#   'user_1154a098',
#   'user_3810cbbc',
#   'user_cd31919a',
#   'user_5d172b77',
#   'user_4f2d2453',
#   'user_e74eff37',
#   'user_4ce97ebe',
#   'user_1f85b573'],
#  ['user_a52bac1e',
#   'well',
#   'afreak',
#   'ive',
#   'always',
#   'intrigued',
#   'see',
#   'two',
#   'midget',
#   'doggystyle',
#   'see',
#   'lift',
#   'leg',
#   'lol'],
#  ['want',
#   'get',
#   'feature',
#   'swiff',
#   'today',
#   'get',
#   'today',
#   'rainy',
#   'price',
#   '7500',
#   'time',
#   'running'],
#  ['user_b0c117e2', 'awwww', 'ull', 'alright'],
#  ['user_ad1393a0',
#   'man',
#   'sac',
#   'putting',
#   'mad',
#   'work',
#   'take',
#   'next',
#   'level',
#   'dont',
#   'ar',
#   'send',
#   'way'],
#  ['natalie',
#   'cole',
#   'thick',
#   'yo',
#   'mean',
#   'didnt',
#   'know',
#   'booty',
#   'thick',
#   'round'],
#  ['im', 'hungry', 'eat', 'eat', 'soul', 'food', 'spot', 'sacramento', 'sux'],
#  ['user_0d9d028d', 'hit', 'user_4a390009'],
#  ['user_6113e677s',
#   'debut',
#   'album',
#   'porch',
#   'politician',
#   'coming',
#   'soon',
#   'feature',
#   'user_0f2298e5',
#   'user_70a1f5e1',
#   'user_d5a480d1',
#   'chris',
#   'classic',
#   'jones'],
#  ['indubiditly',
#   'pimpin',
#   'rt',
#   'user_885a0f47',
#   'user_6113e677',
#   'dig',
#   '1luv'],
#  ['letsbereal',
#   'half',
#   'time',
#   'type',
#   'lol',
#   'aint',
#   'really',
#   'laughing',
#   'lol'],
#  ['user_a090274a',
#   'hey',
#   'hey',
#   'made',
#   'trnding',
#   'topic',
#   'see',
#   'top',
#   'timeline'],
#  ['user_d1dc1eea',
#   'last',
#   'nigga',
#   'wasnt',
#   'eating',
#   'desert',
#   'right',
#   'lmao'],
#  ['2nite',
#   'user_4b217ebf',
#   'blue',
#   'cue',
#   '28th',
#   'jst',
#   'bsmoove',
#   'video',
#   'release',
#   'perf',
#   'user_6113e677',
#   'user_0f2298e5',
#   'user_6fa634bd',
#   'biggest',
#   'party',
#   '2010'],
#  ['rt',
#   'user_6fa634bd',
#   '2nite',
#   'user_4b217ebf',
#   'blue',
#   'cue',
#   '28th',
#   'jst',
#   'bsmoove',
#   'video',
#   'release',
#   'perf',
#   'user_6113e677',
#   'user_0f2298e5',
#   'user_6fa634bd'],
#  ['letsbereal', 'would', 'great', 'asset', 'user_259b7aad'],
#  ['wink', 'back', 'like', 'rt', 'user_6ee8701a', 'user_6113e677'],
#  ['user_4fa8d7b8', 'u', 'right', 'lol', 'vday', 'savior'],
#  ['user_b0c117e2',
#   'yallaint',
#   'blue',
#   'que',
#   'tonight',
#   'gettin',
#   'ya',
#   'grown',
#   'sexy',
#   'dayum',
#   'shame'],
#  ['user_469fb34e',
#   'lol',
#   'slide',
#   'thru',
#   'boy',
#   'ha',
#   'drank',
#   'wit',
#   'b4',
#   'rock',
#   'mic'],
#  ['there',
#   'thick',
#   '1z',
#   'buildin',
#   'tonight',
#   'yall',
#   'bring',
#   'yall',
#   'lazy',
#   'ass',
#   'blue',
#   'que',
#   'right'],
#  ['brotha',
#   'user_0f2298e5',
#   'made',
#   'crack',
#   'tonite',
#   'along',
#   'bsmoove',
#   'nigga',
#   'putting',
#   'sac',
#   'map'],
#  ['im',
#   'drunk',
#   'u',
#   'dont',
#   'like',
#   'im',
#   'saying',
#   'right',
#   'fuck',
#   'u',
#   'twice',
#   'im',
#   'zone',
#   'right',
#   'struggle',
#   'mobb',
#   'gorillaz'],
#  ['sacramento', 'stand', 'fuck'],
#  ['make',
#   'sure',
#   'im',
#   'ok',
#   'nigg',
#   'rt',
#   'user_3ba76e25',
#   'user_6113e677',
#   'sound',
#   'like',
#   'drinkin',
#   'yaaadddaaaa',
#   'juice',
#   'haha'],
#  ['user_cea09a31', 'nigga', 'boommlan', 'jus', 'leavin', 'club', 'lmao'],
#  ['rt', 'user_6aaddb22', 'u', 'know', 'live', 'come', 'thru'],
#  ['follow',
#   'user_469fb34e',
#   'real',
#   'nigga',
#   'plus',
#   'one',
#   'gorilla',
#   'niggaz'],
#  ['user_f94a4154',
#   'big',
#   'wherever',
#   'go',
#   'brew',
#   'city',
#   'city',
#   'fam',
#   'get',
#   'a1',
#   'treatment'],
#  ['jus',
#   'waking',
#   'dont',
#   'think',
#   'hangover',
#   'im',
#   'starving',
#   'like',
#   'mudafucka',
#   'whats',
#   'good',
#   'twitter',
#   'thanks',
#   'follow',
#   'friday'],
#  ['dont', 'judge', 'men', 'nigga', 'swiff', 'fly', 'den', 'mudda', 'fuckka'],
#  ['rt',
#   'user_3edd4846',
#   'rt',
#   'user_6113e677',
#   'set',
#   'twitter',
#   'page',
#   'called',
#   'user_cb809a90',
#   'pray',
#   'youngster',
#   'find',
#   'jkwon'],
#  ['rt', 'user_8dc6d221', 'signed', 'wwwtwtmuziknet'],
#  ['user_cd2739f0', 'let', 'start', 'hug', 'push', 'cali', 'bruh', 'hit'],
#  ['thats', 'global'],
#  ['user_f63ea717', 'wheres', 'italiano', 'sweetie'],
#  ['rt',
#   'user_5246313b',
#   'big',
#   'shot',
#   'user_a92a70ef',
#   'user_4f2d2453',
#   'user_05450bff',
#   'user_6113e677',
#   'user_90a96557',
#   'user_e0f62a8c',
#   'user_45a74dba'],
#  ['user_ce248072', 'studio', 'boo'],
#  ['user_dd658232', 'nah', 'might', 'record', '1', 'tonight'],
#  ['nigga', 'crackin', 'ovr', 'arguing', 'ovr', 'ppl', 'argue', 'funny'],
#  ['rt',
#   'user_018c460e',
#   'u',
#   'claim',
#   'u',
#   'really',
#   'didnt',
#   'even',
#   'spell',
#   'name',
#   'right',
#   'gt',
#   'user_74bdeaab'],
#  ['user_a2412931',
#   'club',
#   'ritz',
#   'finna',
#   'splash',
#   'hard',
#   'young',
#   'dro',
#   'next',
#   'week',
#   'heard'],
#  ['attn',
#   'producer',
#   'beat',
#   'battle',
#   'user_687037e6',
#   'sacramento',
#   'u',
#   'think',
#   'u',
#   'got',
#   'beat',
#   'hurry',
#   'get'],
#  ['user_f8f83d1d', 'hate', 'say', 'tarheel', 'lol'],
#  ['shoutout',
#   'boy',
#   'boy',
#   'user_62dfe089',
#   'giving',
#   'song',
#   'opp',
#   'heard',
#   'yall',
#   'follow',
#   'air',
#   'personality',
#   'who',
#   'real',
#   'come'],
#  ['also',
#   'dont',
#   'forget',
#   'follow',
#   'girl',
#   'user_dfa11e46',
#   'mad',
#   'cute',
#   'gangsta'],
#  ['user_a7f1a8f2',
#   'lmao',
#   'got',
#   'day',
#   'dude',
#   'like',
#   'u',
#   'bang',
#   'homie',
#   'answered',
#   '4ch',
#   'u',
#   'failure',
#   'hahaha'],
#  ['user_af0fd431', 'sum1', 'come', 'get'],
#  ['user_dfe2c760', 'let', 'try', 'email', 'ya', 'whas', 'gmail'],
#  ['user_9e7db6ee',
#   'girl',
#   'went',
#   'sooo',
#   'hard',
#   'sho',
#   'thurs',
#   'got',
#   'footage',
#   'coming',
#   'real',
#   'soon',
#   'club',
#   'blush',
#   'right',
#   'banging',
#   'caligirl'],
#  ['support',
#   'sacramento',
#   'music',
#   'home',
#   'u',
#   'dont',
#   'suck',
#   'southside',
#   'dick',
#   'biotch',
# ...
#   'user_72231711',
#   'ewwwwwww',
#   'lol',
#   'rt',
#   'user_132b30d0',
#   'want',
#   'fukin',
#   'blunt',
#   'rite'],
#  ['nah',
#   'g',
#   'im',
#   'bullshittin',
#   'rt',
#   'user_1bab2868',
#   'rt',
#   'u',
#   'smoke',
#   '5',
#   'user_132b30d0',
#   'want',
#   'fukin',
#   'blunt',
#   'rite'],
#  ['drinkin', 'begin'],
#  ['damn',
#   'hate',
#   'wen',
#   'im',
#   'drinkin',
#   'cant',
#   'unlock',
#   'jak',
#   'always',
#   'fuk',
#   'last',
#   'letter'],
#  ['outta', 'rite'],
#  ['loli',
#   'cant',
#   'sleepy',
#   'u',
#   'punkass',
#   'rt',
#   'user_25ca3bc5',
#   'take',
#   'as',
#   'sleep',
#   'rt',
#   'user_132b30d0',
#   'wtf',
#   'still',
#   'doin'],
#  ['user_2a69d24d',
#   'lolthats',
#   'somethin',
#   'u',
#   'learn',
#   'u',
#   'go',
#   'suppose',
#   'kno',
#   '67th',
#   'grade'],
#  ['cant', 'sleep'],
#  ['say', 'everyday', 'rt', 'user_d00162e2', 'bitch', 'crazy'],
#  ['im', 'wit', 'fukin', 'headache', 'effect', 'drinking', 'motherfucker'],
#  ['hellno',
#   'man',
#   'sadshit',
#   'rt',
#   'user_f1aeaee5',
#   'user_132b30d0',
#   'dont',
#   'make',
#   'sense',
#   'lol'],
#  ['user_2f7ac093', 'yo', 'nice', 'wen', 'u', 'get', 'bakklr', 'lessonswassup'],
#  ['iight',
#   'bet',
#   'rt',
#   'user_e20feb2b',
#   'user_132b30d0',
#   'lol',
#   'already',
#   'gon',
#   'c',
#   'wats',
#   'wat'],
#  ['user_f1b8eec7', 'watchu', 'kiddo'],
#  ['damn', 'im', 'fuckin', 'stuck'],
#  ['im', 'bak', 'upwho', 'hell', 'wit'],
#  ['yo',
#   'user_45350237',
#   'tellin',
#   'drinkin',
#   'patron',
#   'alreadybetta',
#   'leave',
#   'house'],
#  ['missed',
#   'like',
#   '6',
#   'call',
#   'think',
#   'promised',
#   'like',
#   '4',
#   'people',
#   'would',
#   'come',
#   'sleeptalking',
#   'lol',
#   'im',
#   'goin',
#   'get',
#   'chickn',
#   'spaghetti'],
#  ['user_4b595545', 'lol', 'thanks', 'heyyy', 'unkie'],
#  ['user_ba67c4ad', 'iono', 'friesand', 'sumn', 'else', 'dont', 'yet'],
#  ['rt',
#   'user_ba67c4ad',
#   'bout',
#   'put',
#   'american',
#   'idolonly',
#   'cu',
#   'im',
#   'watchin'],
#  ['user_ba414f2c', 'lol', 'mmhmm'],
#  ['user_deea6677', 'u', 'gon', 'na', 'go', 'da', 'chapp', 'wit'],
#  ['first',
#   'season',
#   'watching',
#   'american',
#   'idol',
#   'since',
#   'reuben',
#   'studdard',
#   'lol',
#   'season',
#   'suck',
#   'based',
#   'episode'],
#  ['rt',
#   'user_ba67c4ad',
#   'user_d886bd3a',
#   'yyeessss',
#   'natural',
#   'high',
#   'high',
#   'life',
#   'babbbbyyyy',
#   'jus',
#   'gim',
#   'money',
#   'food',
#   'im',
#   'highlol',
#   'mess'],
#  ['user_c367d89f', 'da', 'chapp'],
#  ['user_ba67c4ad', 'lol'],
#  ['user_5d53ec7a', 'quit', 'wut', 'formspring'],
#  ['user_92ea6fb5', 'hush', 'one', 'asked', 'u'],
#  ['user_ef5981b2', 'boy', 'find', 'u', 'somebody', 'play', 'wit', 'lol'],
#  ['rt',
#   'user_44a7a208',
#   'seems',
#   'like',
#   'user_d886bd3a',
#   'never',
#   'sleep',
#   'lol',
#   'wonder',
#   'he',
#   'hhhhmwut',
#   'u',
#   'mean',
#   'lol',
#   'jus',
#   'woke',
#   'exact'],
#  ['rt',
#   'user_ef5981b2',
#   'user_d886bd3a',
#   'lmao',
#   'haha',
#   'well',
#   'go',
#   'play',
#   'person',
#   'foundu',
#   'bein',
#   'mess',
#   'wow',
#   'get',
#   'yur',
#   'life',
#   'bff'],
#  ['user_ba414f2c', 'perfect', 'respect'],
#  ['user_ba414f2c', 'damaging', 'ur', 'temple'],
#  ['user_ef5981b2', 'user_ee5569c8', 'ugh', 'ever', 'sleep', 'bestie'],
#  ['im', 'really', 'headed', 'job', 'n', 'night', 'clothes', 'crox', 'wow'],
#  ['user_daeebe46', 'lol', 'hows', 'school'],
#  ['user_daeebe46', 'great', 'im', 'da', 'way', 'take', 'drug', 'test'],
#  ['want', 'take', 'eat'],
#  ['phone', 'dying'],
#  ['user_937e3684', 'rite', 'hur', 'rite', 'right', 'herr'],
#  ['user_daeebe46', 'lol', 'dat', 'show', 'love'],
#  ['im',
#   'n',
#   'drug',
#   'test',
#   'building',
#   'run',
#   'mrhayton',
#   'khan',
#   'va',
#   'friend'],
#  ['hope',
#   'car',
#   'crank',
#   'cu',
#   'need',
#   'make',
#   'dis',
#   'damn',
#   'bank',
#   'close'],
#  ['need', 'new', 'battery', 'battery', 'equal', 'new', 'cell'],
#  ['user_ba67c4ad', 'atm', 'card', 'jus', 'started', 'banking'],
#  ['user_ba67c4ad', 'dont', 'jus', 'took', 'shop', 'told', 'dop', 'wutever'],
#  ['user_db38d8c2',
#   'car',
#   'n',
#   'shop',
#   'wait',
#   'people',
#   'people',
#   'jus',
#   'gettin',
#   'nerve'],
#  ['user_ba67c4ad', 'sound', 'good'],
#  ['time', 'lay'],
#  ['rt',
#   'user_4b595545',
#   'hmmmmmm',
#   'hey',
#   'mr',
#   'carta',
#   'hey',
#   'u',
#   'loli',
#   'great',
#   'u',
#   'lol'],
#  ['user_65cd34dc', 'lol', 'oh', 'okay'],
#  ['mike', 'sooo', 'high', 'laughin', 'dis', 'fat', 'lady', 'face', 'window'],
#  ['user_2c710b58', 'lol', 'ohh', 'yahh', 'cam'],
#  ['user_effb52b6', 'lol'],
#  ['hmmmm', 'user_200be794'],
#  ['morning', 'world'],
#  ['lol', 'bein', 'freaky', 'wit', 'u'],
#  ['user_daeebe46', 'aweee', 'cute', 'knotz'],
#  ['people', 'get', 'pleasure', 'ouit', 'attention', 'get', 'boy', 'ugh'],
#  ['user_1b0b177b', 'lol', 'r', 'u', 'computer'],
#  ['da',
#   'ace',
#   'da',
#   'phone',
#   'wit',
#   'mom',
#   'u',
#   'lookin',
#   'girl',
#   'mom',
#   'much',
#   'goin',
#   'wen',
#   'wont',
#   'much',
#   'goin',
#   'u',
#   'wont',
#   'lookin',
#   'clockedtea',
#   'lol'],
#  ['user_417c1789', 'yeah', 'u', 'cam'],
#  ['user_ba67c4ad', 'hmmm'],
#  ['okay',
#   'im',
#   'pissed',
#   'beyond',
#   'measure',
#   'wan',
#   'na',
#   'go',
#   'back',
#   'home'],
#  ['rt',
#   'user_92ea6fb5',
#   'user_d886bd3a',
#   'u',
#   'never',
#   'miss',
#   'good',
#   'thing',
#   'till',
#   'gonebitch',
#   'im',
#   'better',
#   'den',
#   'good',
#   'im',
#   'great'],
#  ['ummm',
#   'since',
#   'im',
#   'forced',
#   'tonight',
#   'im',
#   'going',
#   'dress',
#   'really',
#   'plain',
#   'cu',
#   'dont',
#   'want',
#   'people',
#   'like',
#   'last',
#   'week',
#   'atllive'],
#  ['user_200be794', 'ooops', 'dont', 'dat'],
#  ['rt',
#   'user_7a949e1d',
#   'user_d886bd3a',
#   'omg',
#   'never',
#   'knew',
#   'u',
#   'following',
#   'lil',
#   'daddyso',
#   'guess',
#   'da',
#   'new',
#   'nickname'],
#  ['user_ba67c4ad', 'exit', '91', '85', 'north'],
#  ['sooo', 'back', 'n', 'boy', 'clothes', 'tonight', 'lol'],
#  ['user_ba67c4ad',
#   'lol',
#   'im',
#   'n',
#   'da',
#   'ballroom',
#   'part',
#   'da',
#   'floor',
#   'lookin',
#   'trade'],
#  ['user_a915305c', 'n', 'da', 'ballroom', 'da', 'middle', 'floor'],
#  ['user_7df72a04', 'cool'],
#  ['ohh', 'noo', 'dey', 'paid', '50', 'get', 'n'],
#  ['hope', 'drummer', 'done', 'night'],
#  ['trade',
#   'face',
#   'yah',
#   'u',
#   'one',
#   'rehected',
#   'u',
#   'git',
#   'girlfriend',
#   'u',
#   'n',
#   'face',
#   'da',
#   'mall',
#   'late'],
#  ['let', 'u', 'gooooo'],
#  ['user_ba67c4ad',
#   'u',
#   'home',
#   'already',
#   'jus',
#   'danced',
#   'wit',
#   'u',
#   '2mins',
#   'ago',
#   'lol',
#   'im',
#   'almost',
#   'home'],
#  ['user_66dee6d2', 'wut', 'u'],
#  ['user_ba67c4ad', 'would', 'u'],
#  ['user_a0249eb3',
#   'dont',
#   'say',
#   'hereand',
#   'oh',
#   'okay',
#   'im',
#   'sure',
#   'u',
#   'goin',
#   'move',
#   'dere',
#   'goin',
#   'stay',
#   'wit',
#   'u',
#   'sizzle'],
#  ['lolhmmm15', 'day'],
#  ['user_65cd34dc', 'lol', 'ur', 'mess'],
#  ['user_ba414f2c', 'lol', 'u', 'come', 'visit', 'ur', 'bday', 'friend'],
#  ['user_a33b1586', 'wuddup', 'lil', 'head'],
#  ['user_ba414f2c',
#   'yep',
#   'yep',
#   'plenty',
#   'money',
#   'u',
#   'pay',
#   'room',
#   'boardand',
#   'way',
#   'club',
#   'celebrate'],
#  ['think',
#   'stop',
#   'tellin',
#   'cousin',
#   'feelcus',
#   'sometimes',
#   'best',
#   'keep',
#   'thing',
#   'urself',
#   'imlearning'],
#  ['user_92ea6fb5', 'lol'],
#  ['user_92ea6fb5', 'lolwell', 'goin', 'fall', 'thru', 'bet'],
#  ['brother',
#   'devonte',
#   'wednesday',
#   'morning',
#   'yay',
#   'think',
#   'goin',
#   'montgomery',
#   'friday',
#   'hmmm'],
#  ['nowplaying', 'keyshia', 'cole', 'youve', 'changed'],
#  ['user_ba414f2c', 'lol', 'otay', 'puntah'],
#  ['user_8ebdb462', 'u', 'bout', 'get', 'n', 'drink', 'im', 'sure'],
#  ['user_7df72a04', 'u'],
#  ['user_7df72a04', 'ugh'],
#  ['rt',
#   'user_24b98296',
#   'user_66dee6d2',
#   'user_580329db',
#   'shade',
#   'wasnt',
#   'invitedme',
#   'either'],
#  ['user_ba414f2c', 'lol'],
#  ['user_508e745e', 'sup'],
#  ['yayyyy',
#   'papa',
#   'john',
#   'fucked',
#   'get',
#   'free',
#   'order',
#   'wing',
#   'cinnamon',
#   'stix',
#   'wenever',
#   'want',
#   'cu',
#   'told',
#   'dont',
#   'want',
#   'dey',
#   'pizza'],
#  ['told',
#   'storm',
#   'past',
#   'storm',
#   'u',
#   'cant',
#   'last',
#   'go',
#   'away',
#   'command',
#   'u',
#   'move',
#   'today',
#   'thats',
#   'told',
#   'storm'],
#  ['user_868f56e2',
#   'went',
#   'to0',
#   'kp',
#   'came',
#   'baqq',
#   'to0',
#   'madiison',
#   'went',
#   'to0',
#   'track',
#   'saw',
#   'madd',
#   'head',
#   'buh',
#   'nuttin',
#   'aiint',
#   'happen'],
#  ['lmao0',
#   'mii',
#   'dai',
#   'still',
#   'p0ppin',
#   'hahahahaha',
#   '2morr0w',
#   'gon',
#   'na',
#   'even',
#   'fun'],
#  ['user_2a55d7ec', 'yeah', 'man', 'smfh', 'yo0', 'liike', 'da'],
#  ['user_9dc999d2', 'stupid', 'biitches'],
#  ['user_810694d8', 'u', 'noe', 'lmao0'],
#  ['user_15a92b64', 'hey', 'buddie'],
#  ['user_7029f7dc', 'iight'],
#  ['wat', 'kind', 'man', 'u', 'u', 'man'],
#  ['user_6f8cbb4a', 'huh'],
#  ['sdepressed', 'uugghh', 'iit', 'eva', 'go0', 'away'],
#  ['juss',
#   'cummin',
#   'home',
#   'practiice',
#   'uuggh',
#   'coach',
#   'clarke',
#   'buggin',
#   'tiimes'],
#  ['user_4cf09774',
#   'waiit',
#   'so0',
#   'who0',
#   'saw',
#   'tha',
#   'tweet',
#   'cuzz',
#   'n0w',
#   'im',
#   'gettin',
#   'tiight'],
#  ['user_4cf09774', 'lmao0', 'blo0dclat', 'man'],
#  ['user_59a4c798', 'im', 'hungry'],
#  ['user_59a4c798', 'fight'],
#  ['user_59a4c798', 'naw', 'chill', 'dont', 'wan', 'na', 'hurt', 'u', 'agaiin'],
#  ['user_eb240fc8',
#   'thinkin',
#   'goiin',
#   'to0',
#   'tha',
#   'moviiesz',
#   '2morr0w',
#   'buh',
#   'tha',
#   'person',
#   'goin',
#   'madd',
#   'so0',
#   'idk',
#   'still',
#   'want',
#   '2'],
#  ['depression',
#   'iisz',
#   'killin',
#   'liike',
#   'omg',
#   'every',
#   'fuccin',
#   'daii',
#   'im',
#   'cryiin',
#   'liike',
#   'ugh',
#   'wish',
#   'iit',
#   'wudd',
#   'st0p'],
#  ['user_59a4c798', 'chill', 'u', 'neva', 'tha', 'type'],
#  ['user_f30f60dd', 'hey', 'siis'],
#  ['2',
#   'freshmesn',
#   'hadd',
#   'fiight',
#   'shiit',
#   'fuccin',
#   'whack',
#   'even',
#   'doe',
#   'one',
#   'got',
#   'liip',
#   'bust'],
#  ['user_ac99adee', 'lmao0', 'ovum', 'giirl'],
#  ['user_33f3eb9d', 'nuttin', 'really', 'juss', 'cummin', 'sko0l', 'y0u'],
#  ['wan',
#   'na',
#   'joiin',
#   'tcbi',
#   'wan',
#   'na',
#   'twirler',
#   'kinda',
#   'liike',
#   'tha',
#   'madiison',
#   'uniform'],
#  ['naw',
#   'da',
#   'answer',
#   'thiis',
#   'question',
#   'user_5c730080',
#   'knock',
#   'lmao0'],
#  ['user_33f3eb9d', 'wat', 'u', 'do0'],
#  ['fuqq', 'dhat', 'shiit', 'want', 'donut', 'co0kiie'],
#  ['user_5c730080',
#   'oo',
#   'okaii',
#   'lmao0',
#   'got',
#   'ta',
#   'tell',
#   'girl',
#   'wat',
#   'time',
#   'got',
#   'ta',
#   'dere'],
#  ['user_0f000fe4', 'wrddd', 'like', 'wth', 'lmaoo', 'wont', 'ite'],
#  ['user_0f000fe4',
#   'yeahhh',
#   'like',
#   'wtf',
#   'niqquh',
#   'u',
#   'find',
#   'twitter',
#   'lol'],
#  ['user_f9ab444e', 'lol', 'knoeee', 'jus', 'peeped'],
#  ['user_70a847ac',
#   'lolll',
#   'pshh',
#   'u',
#   'betta',
#   'niqqus',
#   'might',
#   'fightin',
#   'deadass'],
#  ['user_237dd848',
#   'lmaooo',
#   'hahahaha',
#   'damnnn',
#   'u',
#   'tight',
#   'fam',
#   'good',
#   'thoee',
#   'everybody',
#   'real',
#   'elmont'],
#  ['user_237dd848',
#   'lmaooo',
#   'aintt',
#   'got',
#   'nuffin',
#   'else',
#   'say',
#   'yo',
#   'good',
#   'luck',
#   'ya',
#   'qame',
#   'saturday',
#   'fam',
#   'lol'],
#  ['rt', 'user_38f05fde', 'lmaoo', 'westbury', 'wack', 'as', 'school', 'fact'],
#  ['user_3eb11752', 'yeahh', 'himme'],
#  ['rt',
#   'user_ac054970',
#   'user_3e616ea2',
#   'chyanne',
#   'shut',
#   'upppp',
#   'lol',
#   'u',
#   'tlkn',
#   'nonsense',
#   'wrd',
#   'chy',
#   'money',
#   'quiet',
#   'lol'],
#  ['user_3fee065a',
#   'lol',
#   'nooo',
#   'imjussayin',
#   'dnt',
#   'eva',
#   'try',
#   'get',
#   'aqain',
#   'talkn',
#   'bout',
#   'dnt',
#   'hit',
#   'u'],
#  ['user_3eb11752'],
#  ['user_9a9b855c',
#   'lol',
#   'overtime',
#   'ahhh',
#   'let',
#   'get',
#   'bout',
#   'get',
#   'dis',
#   'dubbb',
#   'lmao'],
#  ['oh', 'yeahhhhhhh'],
#  ['1111', 'make', 'wishhh'],
#  ['rt',
#   'user_d08e604d',
#   'nowplaying',
#   'hold',
#   'yuh',
#   'gyptianlti',
#   'swear',
#   'everybody',
#   'listens',
#   'dis',
#   'songgg',
#   'lol'],
#  ['ff', 'hotwings', 'user_06a38c6b', 'yall', 'lol'],
#  ['ff', 'user_d08e604d', 'sum', 'cool', 'ell', 'eye', 'chick', 'lol'],
#  ['ff', 'boii', 'user_ec22dbeb', 'moon', 'walk', 'hav', 'u', 'goin', 'banana'],
#  ['ff',
#   'boii',
#   'user_4dc6ccf4',
#   'suffolk',
#   'county',
#   'champ',
#   'riite',
#   'yall'],
#  ['user_70a847ac', 'lmao', 'ohh', 'stop', 'frontin', 'little', 'one'],
#  ['user_ec22dbeb',
#   'lmaoo',
#   'das',
#   'illest',
#   'shyt',
#   'ive',
#   'seen',
#   'since',
#   'michael',
#   'jackson'],
#  ['ff', 'user_4e744558', 'cool', 'as', 'uniondale', 'chick'],
#  ['ff', 'user_c0cfaecc', 'anotha', 'cute', 'quiet', 'follower', 'lol'],
#  ['user_b83067cd', 'lmao', 'b', 'like', 'dat', 'man'],
#  ['user_07a73af9',
#   'elmont',
#   'lml',
#   'knoee',
#   'mad',
#   'van',
#   'head',
#   'lol',
#   'u',
#   'comin',
#   'tha',
#   'party',
#   'tonight'],
#  ['wheaa', 'da', 'hoe'],
#  ['user_20d9de32',
#   'lmaooo',
#   'think',
#   'bout',
#   'u',
#   'riite',
#   'ask',
#   'stupid',
#   'as',
#   'question',
#   'swear'],
#  ['user_38f05fde', 'jump', 'bridge', 'p'],
#  ['user_38f05fde', 'yes', 'woman', 'lol'],
#  ['user_48854253', '_______'],
#  ['user_0d5da0ca', 'comin', 'wit', 'u', 'got', 'ride', 'dere'],
#  ['loso', 'kill', 'backdeadass'],
#  ['rt',
#   'user_4a5ba987',
#   'mad',
#   'chick',
#   'son',
#   'deadddaassss',
#   'finna',
#   'turn',
#   'maynee'],
#  ['rt',
#   'user_4a5ba987',
#   'yo',
#   'fckin',
#   'w',
#   'user_9caea090',
#   'shit',
#   'tonight',
#   'lookin',
#   'lik',
#   'gon',
#   'na',
#   'b',
#   'live',
#   'one'],
#  ['user_630818f7', 'niqqa', 'gettin', 'innnnnnn'],
#  ['user_98be9bea', 'lmaooo', 'stupidddd'],
#  ['championship',
#   'game',
#   '2mm',
#   'v',
#   'westbury',
#   'hofstra',
#   '3',
#   'come',
#   'thruuuuu',
#   '6',
#   'get'],
#  ['user_f8fac3d9', 'ohh', 'iiigh'],
#  ['user_f8fac3d9',
#   'lmao',
#   '172',
#   '1',
#   'seed',
#   'hell',
#   'yeahhh',
#   'bout',
#   'clap',
#   'dese',
#   'niqqas',
#   'mann'],
#  ['user_f8fac3d9', 'shyt', 'ohdee', 'liveeeee', 'mann'],
#  ['user_f8fac3d9', 'ohhh', 'iigh', 'das', 'wassuppp', 'den'],
#  ['neva',
#   'seen',
#   'many',
#   'bad',
#   'bitchesx',
#   'fault',
#   'mean',
#   'cute',
#   'gurls',
#   'one',
#   'facility'],
#  ['user_77963b21',
#   'lmaoo',
#   'shutupp',
#   'u',
#   'knoee',
#   'ya',
#   'armm',
#   'sore',
#   'dem',
#   'punch'],
#  ['user_45974504', 'yeahhh', 'im', 'str8'],
#  ['jus', 'woke', 'bout', 'hit', 'barber'],
#  ['user_4a5ba987',
#   'im',
#   'goin',
#   'wit',
#   'uhm',
#   'team',
#   'smh',
#   'im',
#   'tryna',
#   'stay',
#   'qame',
#   'afta',
#   'toouniondale',
#   'v',
#   'baldwin',
#   'maddd',
#   'bitch'],
#  ['user_630818f7',
#   'yo',
#   'ty',
#   'got',
#   'ta',
#   'talk',
#   'u',
#   'get',
#   'tha',
#   'skool',
#   'lol',
#   'u',
#   'tightttttttttt'],
#  ['user_46922d96',
#   'lol',
#   'honestly',
#   'dnt',
#   'remeber',
#   'anybody',
#   'dere',
#   'much',
#   'gurls',
#   'remeber',
#   'lol',
#   'im',
#   'jus',
#   'sickkk',
#   'phone',
#   'died',
#   'end',
#   'smh'],
#  ['user_b68350b2',
#   'ohhdee',
#   'lol',
#   'da',
#   'good',
#   'as',
#   'qame',
#   'rite',
#   'dere',
#   'son'],
#  ['user_46922d96',
#   'lol',
#   'cool',
#   'felt',
#   'like',
#   'danced',
#   'wit',
#   'everybody',
#   'n',
#   'dere',
#   'thoee',
#   'lol'],
#  ['user_f9ab444e', 'watchu', 'mean'],
#  ['user_45974504', '3'],
#  ['user_f9ab444e',
#   'yeah',
#   'went',
#   'smh',
#   'gon',
#   'na',
#   'take',
#   'long',
#   'time',
#   'get',
#   'ovum',
#   'dis'],
#  ['user_f9ab444e',
#   'bri',
#   'smh',
#   'wanted',
#   'dem',
#   'win',
#   'sooo',
#   'baddd',
#   'worked',
#   'hard',
#   'man'],
#  ['user_adaea719', 'nahh', 'buh'],
#  ['rt',
#   'user_1eb7ca81',
#   'rt',
#   'user_93f38144',
#   'owwwww',
#   'shoutouts',
#   'westmoney',
#   'uniondale',
#   'taking',
#   'ship',
#   'year',
#   'ayeeeeezltsmfh'],
#  ['user_8d7adfd4', 'smh', 'seen', 'sum', 'niqqa', 'get', 'snuffed'],
#  ['cant',
#   'sleep',
#   'smh',
#   'jus',
#   'layin',
#   'dark',
#   'thinkin',
#   'bout',
#   'alotta',
#   'shit',
#   'man'],
#  ['user_0d5da0ca', 'smh', 'cant', 'believe', 'dis', 'shyt', 'ovum'],
#  ['user_96bad73a',
#   'yeahh',
#   'buh',
#   'jus',
#   'bcuz',
#   'got',
#   'nxt',
#   'yr',
#   'doesnt',
#   'mean',
#   'aint',
#   'wan',
#   'na',
#   'win',
#   'smh',
#   'im',
#   'sickkkkkkkkkk'],
#  ['nowplaying', 'tupackeep', 'ya', 'head'],
#  ['user_48854253', 'smh', 'idk', 'u', 'feel', 'way'],
#  ['watchin', 'youtube', 'video'],
#  ['goin', 'sleep'],
#  ['rt', 'user_0f000fe4', 'watching', 'gameltu', 'got', 'dvd'],
#  ['rt',
#   'user_3eb11752',
#   'ball',
#   'hand',
#   'time',
#   'noo',
#   'ltant',
#   'chill',
#   'wit',
#   'dat',
#   'shit',
#   'man'],
#  ['rt',
#   'user_f9ab444e',
#   'joke',
#   'aside',
#   'tho',
#   'kinda',
#   'think',
#   'user_1d7d70a1',
#   'hve',
#   'ball',
#   'clutch',
#   'okaylthe'],
#  ...]

# %%
dev_list_of_tweets = []
for tweet in dev_tweetContent:
    dev_list_of_tweets.append(tweet.split())
    
test_list_of_tweets = []
for tweet in test_tweetContent:
    test_list_of_tweets.append(tweet.split())

# %%
cores = multiprocessing.cpu_count()
w2v_model = gensim.models.word2vec.Word2Vec(list_of_tweets, vector_size=100, window=8, min_count=1, sg=1, epochs=30, workers=cores)

# %%
w2v_model.wv.most_similar('donald')
# Out:
# [('trump', 0.8459528088569641),
#  ('user_c28d47f2', 0.8311812877655029),
#  ('lawnwit', 0.8258400559425354),
#  ('user_62fa06b6', 0.812321662902832),
#  ('combover', 0.8016952872276306),
#  ('balmgtctfu', 0.7086427211761475),
#  ('user_8674f459', 0.7012542486190796),
#  ('user_b41c0ce1', 0.6884254217147827),
#  ('user_c241c564', 0.6865020990371704),
#  ('airbrushed', 0.6844445466995239)]

# %%
w2v_words = w2v_model.wv.index_to_key

# %% [markdown]
# ### wAvg W2V

# %%
# average Word2Vec
# compute average word2vec for each tweet
train_vectors = [] # the avg-w2v for each sentence/review is stored in this list
for sent in tqdm(list_of_tweets): # for each tweet
    sent_vec = np.zeros(100) # as word vectors are of zero length 300, 
    cnt_words = 0 # num of words with a valid vector in the sentence/review
    for word in sent: # for each word in a tweet
        if word in w2v_words:
            vec = w2v_model.wv[word]
            sent_vec += vec
            cnt_words += 1
    if cnt_words != 0:
        sent_vec /= cnt_words
    train_vectors.append(sent_vec)
print(len(train_vectors))
print(len(train_vectors[0]))
# Out:
# 100%|██████████| 133795/133795 [08:28<00:00, 263.33it/s]
# 133795
# 100

# %%
dev_vectors = [] # the avg-w2v for each sentence/review is stored in this list
for sent in tqdm(dev_list_of_tweets): # for each tweet
    sent_vec = np.zeros(100) # as word vectors are of zero length 300, 
    cnt_words = 0 # num of words with a valid vector in the sentence/review
    for word in sent: # for each word in a tweet
        if word in w2v_words:
            vec = w2v_model.wv[word]
            sent_vec += vec
            cnt_words += 1
    if cnt_words != 0:
        sent_vec /= cnt_words
    dev_vectors.append(sent_vec)
print(len(dev_vectors))
print(len(dev_vectors[0]))
# Out:
# 100%|██████████| 11475/11475 [01:48<00:00, 105.81it/s]
# 11475
# 100

# %%
from sklearn.linear_model import LogisticRegression

clf = LogisticRegression(n_jobs=-1).fit(train_vectors, train_labels)
predicted_labels = clf.predict(dev_vectors)

accuracy = metrics.accuracy_score(dev_labels, predicted_labels)
print('Accuracy：', '%.4f' % accuracy)
# Out:
# Accuracy： 0.4568

# %%
from sklearn.ensemble import RandomForestClassifier

clf = RandomForestClassifier(max_depth=100, random_state=0, n_jobs=-1).fit(train_vectors, train_labels)
predicted_labels = clf.predict(dev_vectors)

accuracy = metrics.accuracy_score(dev_labels, predicted_labels)
print('Accuracy：', '%.4f' % accuracy)
# Out:
# Accuracy： 0.4342

# %% [markdown]
# ### TFIDF Weighted

# %%
tfidf_dict = dict(zip(word_vectorizer.get_feature_names(), list(word_vectorizer.idf_)))

# %%
# TF-IDF weighted Word2Vec
tfidf_feat = word_vectorizer.get_feature_names() # tfidf words/col-names
# final_tf_idf is the sparse matrix with row= sentence, col=word and cell_val = tfidf

tfidf_sent_vectors = [] # the tfidf-w2v for each sentence/review is stored in this list
row=0
for sent in tqdm(list_of_tweets): # for each review/sentence 
    sent_vec = np.zeros(100) # as word vectors are of zero length
    weight_sum = 0; # num of words with a valid vector in the sentence/review
    for word in sent: # for each word in a review/sentence
        if word in w2v_words and word in tfidf_feat:
            vec = w2v_model.wv[word]
#             tf_idf = tf_idf_matrix[row, tfidf_feat.index(word)]
            # to reduce the computation we are 
            # dictionary[word] = idf value of word in whole courpus
            # sent.count(word) = tf valeus of word in this review
            tf_idf = tfidf_dict[word]*(sent.count(word)/len(sent))
            sent_vec += (vec * tf_idf)
            weight_sum += tf_idf
    if weight_sum != 0:
        sent_vec /= weight_sum
    tfidf_sent_vectors.append(sent_vec)
    row += 1
# Out:
# 100%|██████████| 133795/133795 [11:54<00:00, 187.21it/s]

# %%
# TF-IDF weighted Word2Vec
tfidf_feat = word_vectorizer.get_feature_names() # tfidf words/col-names
# final_tf_idf is the sparse matrix with row= sentence, col=word and cell_val = tfidf

tfidf_dev_vectors = [] # the tfidf-w2v for each sentence/review is stored in this list
row=0
for sent in tqdm(dev_list_of_tweets): # for each review/sentence 
    sent_vec = np.zeros(100) # as word vectors are of zero length
    weight_sum = 0; # num of words with a valid vector in the sentence/review
    for word in sent: # for each word in a review/sentence
        if word in w2v_words and word in tfidf_feat:
            vec = w2v_model.wv[word]
#             tf_idf = tf_idf_matrix[row, tfidf_feat.index(word)]
            # to reduce the computation we are 
            # dictionary[word] = idf value of word in whole courpus
            # sent.count(word) = tf valeus of word in this review
            tf_idf = tfidf_dict[word]*(sent.count(word)/len(sent))
            sent_vec += (vec * tf_idf)
            weight_sum += tf_idf
    if weight_sum != 0:
        sent_vec /= weight_sum
    tfidf_dev_vectors.append(sent_vec)
    row += 1
# Out:
# 100%|██████████| 11475/11475 [02:04<00:00, 92.25it/s]

# %%
from sklearn.linear_model import LogisticRegression

clf = LogisticRegression(n_jobs=-1).fit(tfidf_sent_vectors, train_labels)
predicted_labels = clf.predict(tfidf_dev_vectors)

accuracy = metrics.accuracy_score(dev_labels, predicted_labels)
print('Accuracy：', '%.4f' % accuracy)
# Out:
# Accuracy： 0.4464

# %%
from sklearn.ensemble import RandomForestClassifier

clf = RandomForestClassifier(max_depth=100, random_state=0, n_jobs=-1).fit(tfidf_sent_vectors, train_labels)
predicted_labels = clf.predict(tfidf_dev_vectors)

accuracy = metrics.accuracy_score(dev_labels, predicted_labels)
print('Accuracy：', '%.4f' % accuracy)
# Out:
# Accuracy： 0.4355

# %%
from sklearn.neural_network import MLPClassifier
from sklearn.model_selection import cross_val_score

# %%
clf = MLPClassifier(max_iter=200, verbose=True)

print('corss-val acc:', np.mean(cross_val_score(clf, tfidf_sent_vectors, train_labels, cv=5)))
clf.fit(tfidf_sent_vectors, train_labels)

predictions = clf.predict(tfidf_dev_vectors)
accuracy = metrics.accuracy_score(dev_labels, predicted_labels)
print('Accuracy：', '%.4f' % accuracy)
# Out:
#
# Iteration 122, loss = 1.10946242
# Iteration 123, loss = 1.10955561
# Iteration 124, loss = 1.10943127
# Iteration 125, loss = 1.10919651
# Iteration 126, loss = 1.10953180
# Iteration 127, loss = 1.10867330
# Iteration 128, loss = 1.10891585
# Iteration 129, loss = 1.10876540
# Iteration 130, loss = 1.10859303
# Iteration 131, loss = 1.10852723
# Iteration 132, loss = 1.10809900
# Iteration 133, loss = 1.10808120
# Iteration 134, loss = 1.10773955
# Iteration 135, loss = 1.10821677
# Iteration 136, loss = 1.10789158
# Iteration 137, loss = 1.10845689
# Iteration 138, loss = 1.10802981
# Iteration 139, loss = 1.10778298
# Iteration 140, loss = 1.10760077
# Iteration 141, loss = 1.10735272
# Iteration 142, loss = 1.10736509
# Iteration 143, loss = 1.10759092
# Iteration 144, loss = 1.10690472
# Iteration 145, loss = 1.10700322
# Iteration 146, loss = 1.10734081
# Iteration 147, loss = 1.10708162
# Iteration 148, loss = 1.10687931
# Iteration 149, loss = 1.10692448
# Iteration 150, loss = 1.10651358
# Iteration 151, loss = 1.10668456
# Iteration 152, loss = 1.10658141
# Iteration 153, loss = 1.10663126
# Iteration 154, loss = 1.10643196
# Iteration 155, loss = 1.10640022
# Iteration 156, loss = 1.10667062
# Iteration 157, loss = 1.10650963
# Iteration 158, loss = 1.10612068
# Iteration 159, loss = 1.10633560
# Iteration 160, loss = 1.10604648
# Iteration 161, loss = 1.10587348
# Iteration 162, loss = 1.10574852
# Iteration 163, loss = 1.10603866
# Iteration 164, loss = 1.10575495
# Iteration 165, loss = 1.10574858
# Iteration 166, loss = 1.10569163
# Iteration 167, loss = 1.10532536
# Iteration 168, loss = 1.10570818
# Iteration 169, loss = 1.10543347
# Iteration 170, loss = 1.10516479
# Iteration 171, loss = 1.10513373
# Iteration 172, loss = 1.10522261
# Iteration 173, loss = 1.10500159
# Iteration 174, loss = 1.10516924
# Iteration 175, loss = 1.10489958
# Iteration 176, loss = 1.10488857
# Iteration 177, loss = 1.10534125
# Iteration 178, loss = 1.10498909
# Iteration 179, loss = 1.10457259
# Iteration 180, loss = 1.10471336
# Iteration 181, loss = 1.10420809
# Iteration 182, loss = 1.10469448
# Iteration 183, loss = 1.10447462
# Iteration 184, loss = 1.10425291
# Iteration 185, loss = 1.10393797
# Iteration 186, loss = 1.10444068
# Iteration 187, loss = 1.10399501
# Iteration 188, loss = 1.10392505
# Iteration 189, loss = 1.10400766
# Iteration 190, loss = 1.10402562
# Iteration 191, loss = 1.10414726
# Iteration 192, loss = 1.10419001
# Iteration 193, loss = 1.10370495
# Iteration 194, loss = 1.10395420
# Iteration 195, loss = 1.10408618
# Iteration 196, loss = 1.10350247
# Iteration 197, loss = 1.10359825
# Iteration 198, loss = 1.10351648
# Iteration 199, loss = 1.10333494
# Iteration 200, loss = 1.10363120
# Accuracy： 0.4355

# %%
from sklearn.tree import DecisionTreeClassifier

clf = DecisionTreeClassifier(random_state=0).fit(tfidf_sent_vectors, train_labels)

predicted_labels = clf.predict(tfidf_dev_vectors)

accuracy = metrics.accuracy_score(dev_labels, predicted_labels)
print('Accuracy：', '%.4f' % accuracy)
# Out:
# Accuracy： 0.3431
